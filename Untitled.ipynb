# %%
import glob
import tabix
import csv
import numpy as np

from itertools import groupby
from operator import itemgetter

import pyranges as pr
import pandas as pd

# %%
file = 'results/coverage/191010_D00501_0366_BH5JWHBCX3_15M03950_depth_of_coverage.csv.gz'
bed = 'config/IlluminaTruSightOne/IlluminaTruSightOne_ROI_b37.bed'

# %%
tb = tabix.open(file)

# %%
bed_list = []
with open(bed) as csvfile:
    spamreader = csv.reader(csvfile, delimiter='\t')
    for row in spamreader:
        bed_list.append(row)

# %%
bed_list
# Out:
# [['1', '955532', '955773'],
#  ['1', '957560', '957862'],
#  ['1', '970636', '970724'],
#  ['1', '976024', '976280'],
#  ['1', '976532', '976797'],
#  ['1', '976837', '977102'],
#  ['1', '977315', '977562'],
#  ['1', '978598', '978857'],
#  ['1', '978897', '979132'],
#  ['1', '979182', '979423'],
#  ['1', '979468', '979657'],
#  ['1', '979693', '979839'],
#  ['1', '980520', '980677'],
#  ['1', '980718', '980923'],
#  ['1', '981092', '981276'],
#  ['1', '981323', '981488'],
#  ['1', '981519', '981665'],
#  ['1', '981756', '982135'],
#  ['1', '982179', '982357'],
#  ['1', '982686', '982854'],
#  ['1', '982932', '983087'],
#  ['1', '983135', '983295'],
#  ['1', '983371', '983765'],
#  ['1', '984226', '984459'],
#  ['1', '984595', '984851'],
#  ['1', '984925', '985195'],
#  ['1', '985262', '985437'],
#  ['1', '985592', '985729'],
#  ['1', '985786', '985991'],
#  ['1', '986085', '986237'],
#  ['1', '986612', '986769'],
#  ['1', '986812', '987045'],
#  ['1', '987087', '987215'],
#  ['1', '989112', '989377'],
#  ['1', '989807', '989951'],
#  ['1', '990183', '990381'],
#  ['1', '1146917', '1147025'],
#  ['1', '1147063', '1147232'],
#  ['1', '1147301', '1147538'],
#  ['1', '1147997', '1148104'],
#  ['1', '1148351', '1148493'],
#  ['1', '1149022', '1149185'],
#  ['1', '1149342', '1149527'],
#  ['1', '1167638', '1168665'],
#  ['1', '1266705', '1266936'],
#  ['1', '1266997', '1267338'],
#  ['1', '1267383', '1268206'],
#  ['1', '1268280', '1268524'],
#  ['1', '1268618', '1268779'],
#  ['1', '1268865', '1269861'],
#  ['1', '1634328', '1634458'],
#  ['1', '1634498', '1634728'],
#  ['1', '1634894', '1635083'],
#  ['1', '1635242', '1635399'],
#  ['1', '1635457', '1635605'],
#  ['1', '1635641', '1635803'],
#  ['1', '1635968', '1636114'],
#  ['1', '1636322', '1636484'],
#  ['1', '1637060', '1637191'],
#  ['1', '1638827', '1639043'],
#  ['1', '1639598', '1639704'],
#  ['1', '1640212', '1640411'],
#  ['1', '1640456', '1640592'],
#  ['1', '1640936', '1641099'],
#  ['1', '1643682', '1643859'],
#  ['1', '1647764', '1647937'],
#  ['1', '1653014', '1653170'],
#  ['1', '1654126', '1654277'],
#  ['1', '1950842', '1950950'],
#  ['1', '1956360', '1956513'],
#  ['1', '1956752', '1956860'],
#  ['1', '1956936', '1957197'],
#  ['1', '1958995', '1959118'],
#  ['1', '1959573', '1959751'],
#  ['1', '1960529', '1960725'],
#  ['1', '1960969', '1961221'],
#  ['1', '1961401', '1961738'],
#  ['1', '2160185', '2161194'],
#  ['1', '2234396', '2234562'],
#  ['1', '2234703', '2234859'],
#  ['1', '2235258', '2235561'],
#  ['1', '2235711', '2236044'],
#  ['1', '2237438', '2237709'],
#  ['1', '2237995', '2238224'],
#  ['1', '2337184', '2337293'],
#  ['1', '2337902', '2338078'],
#  ['1', '2338138', '2338414'],
#  ['1', '2339870', '2340317'],
#  ['1', '2341789', '2341910'],
#  ['1', '2343809', '2343961'],
#  ['1', '2522411', '2522548'],
#  ['1', '2522975', '2523092'],
#  ['1', '2523350', '2523486'],
#  ['1', '2524073', '2524179'],
#  ['1', '2524251', '2524425'],
#  ['1', '2525232', '2525392'],
#  ['1', '2525803', '2525902'],
#  ['1', '2526208', '2526352'],
#  ['1', '2526694', '2526818'],
#  ['1', '2527427', '2527566'],
#  ['1', '2527979', '2528148'],
#  ['1', '2529625', '2529759'],
#  ['1', '2530072', '2530249'],
#  ['1', '2535302', '2535432'],
#  ['1', '2535565', '2535740'],
#  ['1', '2536976', '2537082'],
#  ['1', '2537666', '2537825'],
#  ['1', '2538392', '2538528'],
#  ['1', '2540757', '2540878'],
#  ['1', '2541088', '2541290'],
#  ['1', '2542699', '2542799'],
#  ['1', '2543545', '2543663'],
#  ['1', '2560749', '2560943'],
#  ['1', '3598909', '3599014'],
#  ['1', '3599603', '3599764'],
#  ['1', '3607449', '3607528'],
#  ['1', '3624092', '3624375'],
#  ['1', '3638564', '3638791'],
#  ['1', '3639897', '3640053'],
#  ['1', '3643658', '3643808'],
#  ['1', '3644171', '3644354'],
#  ['1', '3644672', '3644801'],
#  ['1', '3645870', '3646032'],
#  ['1', '3646543', '3646732'],
#  ['1', '3647470', '3647649'],
#  ['1', '3648006', '3648140'],
#  ['1', '3649290', '3649660'],
#  ['1', '5923304', '5923485'],
#  ['1', '5923929', '5924113'],
#  ['1', '5924377', '5924597'],
#  ['1', '5925141', '5925353'],
#  ['1', '5926412', '5926538'],
#  ['1', '5927069', '5927195'],
#  ['1', '5927779', '5927976'],
#  ['1', '5933291', '5933415'],
#  ['1', '5934510', '5934737'],
#  ['1', '5934913', '5935180'],
#  ['1', '5937132', '5937378'],
#  ['1', '5940153', '5940319'],
#  ['1', '5947325', '5947546'],
#  ['1', '5950907', '5951108'],
#  ['1', '5964656', '5964884'],
#  ['1', '5965331', '5965563'],
#  ['1', '5965671', '5965863'],
#  ['1', '5967154', '5967302'],
#  ['1', '5969191', '5969293'],
#  ['1', '5987688', '5987867'],
#  ['1', '5993186', '5993409'],
#  ['1', '6007143', '6007310'],
#  ['1', '6008109', '6008331'],
#  ['1', '6012739', '6012916'],
#  ['1', '6021833', '6022029'],
#  ['1', '6027338', '6027443'],
#  ['1', '6029126', '6029339'],
#  ['1', '6038309', '6038493'],
#  ['1', '6046194', '6046369'],
#  ['1', '6100608', '6100725'],
#  ['1', '6101870', '6101952'],
#  ['1', '6111576', '6111834'],
#  ['1', '6132794', '6132878'],
#  ['1', '6133772', '6133850'],
#  ['1', '6142234', '6142354'],
#  ['1', '6145243', '6145328'],
#  ['1', '6147506', '6147591'],
#  ['1', '6149047', '6149131'],
#  ['1', '6150428', '6150555'],
#  ['1', '6151302', '6151387'],
#  ['1', '6154439', '6154565'],
#  ['1', '6155362', '6155523'],
#  ['1', '6155569', '6155704'],
#  ['1', '6156675', '6156836'],
#  ['1', '6157308', '6157437'],
#  ['1', '6158524', '6158651'],
#  ['1', '6484995', '6485329'],
#  ['1', '6488265', '6488499'],
#  ['1', '6500293', '6500520'],
#  ['1', '6500665', '6500888'],
#  ['1', '6500973', '6501145'],
#  ['1', '6504520', '6504762'],
#  ['1', '6505703', '6506015'],
#  ['1', '6508680', '6509171'],
#  ['1', '6511642', '6511828'],
#  ['1', '6511872', '6512176'],
#  ['1', '6517223', '6517343'],
#  ['1', '6517400', '6517452'],
#  ['1', '6520038', '6520226'],
#  ['1', '6521476', '6521842'],
#  ['1', '6522033', '6522254'],
#  ['1', '6522668', '6522746'],
#  ['1', '6522902', '6523050'],
#  ['1', '6523104', '6523227'],
#  ['1', '6524413', '6524533'],
#  ['1', '6524591', '6524799'],
#  ['1', '6525127', '6525302'],
#  ['1', '6525479', '6525640'],
#  ['1', '6526108', '6526187'],
#  ['1', '6527602', '6527652'],
#  ['1', '6527864', '6528666'],
#  ['1', '6529081', '6529321'],
#  ['1', '6529374', '6529530'],
#  ['1', '6529583', '6529756'],
#  ['1', '6530275', '6530435'],
#  ['1', '6530545', '6530723'],
#  ['1', '6530774', '6530964'],
#  ['1', '6531029', '6531180'],
#  ['1', '6531527', '6531717'],
#  ['1', '6531797', '6531888'],
#  ['1', '6532566', '6532702'],
#  ['1', '6533025', '6533254'],
#  ['1', '6533290', '6533534'],
#  ['1', '6534052', '6534244'],
#  ['1', '6534490', '6534667'],
#  ['1', '6535086', '6535218'],
#  ['1', '6535501', '6535602'],
#  ['1', '6535970', '6536116'],
#  ['1', '6537568', '6537738'],
#  ['1', '6556532', '6556649'],
#  ['1', '6557359', '6557403'],
#  ['1', '6579484', '6579591'],
#  ['1', '6615413', '6615644'],
#  ['1', '6630948', '6631295'],
#  ['1', '6634670', '6635472'],
#  ['1', '6636454', '6636707'],
#  ['1', '6636989', '6637150'],
#  ['1', '6638692', '6639661'],
#  ['1', '6845570', '6845655'],
#  ['1', '6880220', '6880330'],
#  ['1', '6885131', '6885290'],
#  ['1', '6931796', '6931842'],
#  ['1', '6947693', '6947802'],
#  ['1', '7151343', '7151451'],
#  ['1', '7309530', '7309706'],
#  ['1', '7527869', '7527981'],
#  ['1', '7700439', '7700633'],
#  ['1', '7721765', '7721946'],
#  ['1', '7723392', '7725279'],
#  ['1', '7730950', '7731117'],
#  ['1', '7737638', '7737813'],
#  ['1', '7792487', '7792679'],
#  ['1', '7796383', '7796620'],
#  ['1', '7796970', '7797089'],
#  ['1', '7797294', '7797650'],
#  ['1', '7797998', '7798562'],
#  ['1', '7804874', '7805102'],
#  ['1', '7805884', '7806171'],
#  ['1', '7807749', '7807861'],
#  ['1', '7811238', '7811472'],
#  ['1', '7812498', '7812613'],
#  ['1', '7815677', '7815748'],
#  ['1', '7826498', '7826568'],
#  ['1', '7844917', '7845085'],
#  ['1', '7845480', '7845666'],
#  ['1', '7846760', '7846916'],
#  ['1', '7848084', '7848326'],
#  ['1', '7853999', '7854088'],
#  ['1', '7858564', '7858753'],
#  ['1', '7861152', '7861271'],
#  ['1', '7863086', '7863233'],
#  ['1', '7863731', '7863928'],
#  ['1', '7868932', '7869078'],
#  ['1', '7869932', '7870101'],
#  ['1', '7870477', '7870647'],
#  ['1', '7879324', '7879500'],
#  ['1', '7880154', '7880319'],
#  ['1', '7880506', '7880720'],
#  ['1', '7886519', '7886790'],
#  ['1', '7887157', '7887895'],
#  ['1', '7889876', '7890241'],
#  ['1', '7895801', '7896025'],
#  ['1', '7897038', '7897229'],
#  ['1', '7902711', '7902832'],
#  ['1', '7907808', '7907962'],
#  ['1', '7909679', '7909763'],
#  ['1', '7910851', '7911002'],
#  ['1', '7912940', '7913083'],
#  ['1', '7913346', '7913511'],
#  ['1', '8022825', '8022955'],
#  ['1', '8025363', '8025505'],
#  ['1', '8029384', '8029484'],
#  ['1', '8030933', '8031043'],
#  ['1', '8037691', '8037818'],
#  ['1', '8044933', '8045134'],
#  ['1', '8921401', '8921508'],
#  ['1', '8922925', '8923024'],
#  ['1', '8923273', '8923422'],
#  ['1', '8923929', '8924171'],
#  ['1', '8925323', '8925561'],
#  ['1', '8926317', '8926580'],
#  ['1', '8927155', '8927329'],
#  ['1', '8928026', '8928136'],
#  ['1', '8930490', '8930589'],
#  ['1', '8931929', '8932065'],
#  ['1', '8934862', '8934987'],
#  ['1', '9005925', '9006044'],
#  ['1', '9009301', '9009521'],
#  ['1', '9017175', '9017364'],
#  ['1', '9018948', '9019081'],
#  ['1', '9022625', '9022735'],
#  ['1', '9027697', '9027895'],
#  ['1', '9030905', '9031060'],
#  ['1', '9034385', '9034520'],
#  ['1', '9034660', '9034780'],
#  ['1', '9304973', '9305640'],
#  ['1', '9307004', '9307162'],
#  ['1', '9322097', '9322407'],
#  ['1', '9323547', '9324948'],
#  ['1', '9770493', '9770674'],
#  ['1', '9775578', '9775847'],
#  ['1', '9775886', '9776156'],
#  ['1', '9776477', '9776697'],
#  ['1', '9776996', '9777186'],
#  ['1', '9777574', '9777704'],
#  ['1', '9778731', '9778993'],
#  ['1', '9779958', '9780095'],
#  ['1', '9780149', '9780320'],
#  ['1', '9780648', '9780739'],
#  ['1', '9780779', '9780987'],
#  ['1', '9781164', '9781326'],
#  ['1', '9781481', '9781665'],
#  ['1', '9781798', '9781938'],
#  ['1', '9782012', '9782231'],
#  ['1', '9782281', '9782434'],
#  ['1', '9782565', '9782684'],
#  ['1', '9783162', '9783370'],
#  ['1', '9784006', '9784170'],
#  ['1', '9784313', '9784499'],
#  ['1', '9784841', '9785014'],
#  ['1', '9786946', '9787124'],
#  ['1', '10032111', '10032266'],
#  ['1', '10035629', '10035853'],
#  ['1', '10041068', '10041248'],
#  ['1', '10042338', '10042776'],
#  ['1', '10292366', '10292512'],
#  ['1', '10316284', '10316401'],
#  ['1', '10318530', '10318750'],
#  ['1', '10321942', '10322048'],
#  ['1', '10327417', '10327636'],
#  ['1', '10328189', '10328341'],
#  ['1', '10331539', '10331657'],
#  ['1', '10332278', '10332384'],
#  ['1', '10335465', '10335581'],
#  ['1', '10336358', '10336477'],
#  ['1', '10338023', '10338206'],
#  ['1', '10342437', '10342611'],
#  ['1', '10351119', '10351239'],
#  ['1', '10352084', '10352200'],
#  ['1', '10355123', '10355243'],
#  ['1', '10355697', '10355844'],
#  ['1', '10356619', '10356743'],
#  ['1', '10356934', '10357155'],
#  ['1', '10357211', '10357324'],
#  ['1', '10363200', '10364725'],
#  ['1', '10380080', '10380214'],
#  ['1', '10381746', '10381935'],
#  ['1', '10383921', '10384140'],
#  ['1', '10384795', '10384973'],
#  ['1', '10386148', '10386437'],
#  ['1', '10394557', '10394716'],
#  ['1', '10396694', '10396820'],
#  ['1', '10397111', '10397281'],
#  ['1', '10397408', '10397611'],
#  ['1', '10399806', '10399937'],
#  ['1', '10402087', '10402246'],
#  ['1', '10403269', '10403365'],
#  ['1', '10405882', '10406031'],
#  ['1', '10407798', '10407905'],
#  ['1', '10408686', '10408811'],
#  ['1', '10412668', '10412814'],
#  ['1', '10420966', '10421121'],
#  ['1', '10421729', '10421903'],
#  ['1', '10423320', '10423422'],
#  ['1', '10425137', '10425323'],
#  ['1', '10425446', '10425726'],
#  ['1', '10428504', '10428616'],
#  ['1', '10431178', '10431340'],
#  ['1', '10434353', '10434543'],
#  ['1', '10434891', '10435124'],
#  ['1', '10435292', '10435451'],
#  ['1', '10436582', '10436665'],
#  ['1', '10459154', '10459202'],
#  ['1', '10459665', '10459781'],
#  ['1', '10460429', '10460649'],
#  ['1', '10463107', '10463213'],
#  ['1', '10464197', '10464356'],
#  ['1', '10468107', '10468217'],
#  ['1', '10471454', '10471629'],
#  ['1', '10473098', '10473328'],
#  ['1', '10477023', '10477194'],
#  ['1', '10477412', '10477586'],
#  ['1', '10478862', '10479002'],
#  ['1', '10479453', '10479616'],
#  ['1', '10479666', '10479823'],
#  ['1', '10535003', '10535079'],
#  ['1', '10555310', '10555398'],
#  ['1', '10596249', '10596374'],
#  ['1', '10659274', '10659443'],
#  ['1', '10678368', '10678494'],
#  ['1', '10683055', '10683198'],
#  ['1', '10684376', '10684514'],
#  ['1', '10687308', '10687440'],
#  ['1', '10689567', '10690064'],
#  ['1', '11073764', '11074042'],
#  ['1', '11076880', '11077084'],
#  ['1', '11078769', '11078950'],
#  ['1', '11080465', '11080676'],
#  ['1', '11082160', '11082731'],
#  ['1', '11086924', '11087725'],
#  ['1', '11090212', '11090327'],
#  ['1', '11090784', '11090959'],
#  ['1', '11094864', '11094983'],
#  ['1', '11097729', '11097888'],
#  ['1', '11102911', '11103099'],
#  ['1', '11103375', '11103612'],
#  ['1', '11104979', '11105030'],
#  ['1', '11105444', '11105616'],
#  ['1', '11106592', '11106810'],
#  ['1', '11106927', '11107196'],
#  ['1', '11107239', '11107284'],
#  ['1', '11333568', '11334137'],
#  ['1', '11345680', '11346208'],
#  ['1', '11850716', '11850975'],
#  ['1', '11851243', '11851403'],
#  ['1', '11852314', '11852456'],
#  ['1', '11853943', '11854166'],
#  ['1', '11854394', '11854615'],
#  ['1', '11854765', '11854940'],
#  ['1', '11855134', '11855425'],
#  ['1', '11856242', '11856476'],
#  ['1', '11860248', '11860399'],
#  ['1', '11861197', '11861476'],
#  ['1', '11862917', '11863193'],
#  ['1', '11906045', '11906091'],
#  ['1', '11907149', '11907516'],
#  ['1', '11907598', '11907761'],
#  ['1', '11917694', '11917748'],
#  ['1', '11918250', '11918546'],
#  ['1', '11918738', '11918910'],
#  ['1', '11994816', '11994932'],
#  ['1', '12008012', '12008144'],
#  ['1', '12009809', '12009983'],
#  ['1', '12010393', '12010597'],
#  ['1', '12012659', '12012812'],
#  ['1', '12014866', '12014970'],
#  ['1', '12016953', '12017091'],
#  ['1', '12017878', '12018020'],
#  ['1', '12018552', '12018724'],
#  ['1', '12020682', '12020844'],
#  ['1', '12023568', '12023713'],
#  ['1', '12024211', '12024377'],
#  ['1', '12024680', '12024862'],
#  ['1', '12025516', '12025670'],
#  ['1', '12026287', '12026393'],
#  ['1', '12027023', '12027168'],
#  ['1', '12030706', '12030893'],
#  ['1', '12032908', '12033074'],
#  ['1', '12034689', '12034885'],
#  ['1', '12049205', '12049420'],
#  ['1', '12052591', '12052767'],
#  ['1', '12056192', '12056395'],
#  ['1', '12057333', '12057498'],
#  ['1', '12058806', '12058955'],
#  ['1', '12059024', '12059172'],
#  ['1', '12061437', '12061631'],
#  ['1', '12061805', '12061913'],
#  ['1', '12062018', '12062180'],
#  ['1', '12064028', '12064195'],
#  ['1', '12064545', '12064690'],
#  ['1', '12064861', '12065004'],
#  ['1', '12065747', '12066008'],
#  ['1', '12066574', '12066770'],
#  ['1', '12067089', '12067326'],
#  ['1', '12069628', '12069803'],
#  ['1', '12071532', '12071642'],
#  ['1', '12081763', '12081917'],
#  ['1', '12082131', '12082519'],
#  ['1', '12082869', '12082994'],
#  ['1', '12089069', '12089218'],
#  ['1', '12089259', '12089358'],
#  ['1', '12089801', '12089971'],
#  ['1', '12090064', '12090201'],
#  ['1', '12091302', '12091480'],
#  ['1', '12091758', '12091882'],
#  ['1', '12227128', '12227246'],
#  ['1', '12248832', '12248972'],
#  ['1', '12250993', '12251162'],
#  ['1', '12251810', '12252000'],
#  ['1', '12252467', '12252601'],
#  ['1', '12252899', '12253175'],
#  ['1', '12253991', '12254109'],
#  ['1', '12254620', '12254695'],
#  ['1', '12262003', '12262248'],
#  ['1', '12266776', '12267094'],
#  ['1', '14042080', '14042129'],
#  ['1', '14057474', '14057632'],
#  ['1', '14059253', '14059397'],
#  ['1', '14068479', '14068672'],
#  ['1', '14075835', '14076002'],
#  ['1', '14099552', '14099703'],
#  ['1', '14112989', '14113039'],
#  ['1', '14142901', '14143085'],
#  ['1', '14149633', '14149696'],
#  ['1', '15764940', '15765020'],
#  ['1', '15766775', '15766907'],
#  ['1', '15766968', '15767106'],
#  ['1', '15768922', '15769088'],
#  ['1', '15769893', '15770070'],
#  ['1', '15771080', '15771266'],
#  ['1', '15772071', '15772264'],
#  ['1', '15773049', '15773104'],
#  ['1', '15819420', '15819550'],
#  ['1', '15820366', '15820516'],
#  ['1', '15821747', '15821967'],
#  ['1', '15831085', '15831273'],
#  ['1', '15832464', '15832594'],
#  ['1', '15833373', '15833590'],
#  ['1', '15834347', '15834422'],
#  ['1', '15844584', '15844910'],
#  ['1', '15850543', '15850715'],
#  ['1', '16091458', '16091748'],
#  ['1', '16093850', '16094078'],
#  ['1', '16095002', '16095145'],
#  ['1', '16096883', '16097093'],
#  ['1', '16101092', '16101543'],
#  ['1', '16103644', '16103802'],
#  ['1', '16111022', '16111173'],
#  ['1', '16342057', '16342274'],
#  ['1', '16343548', '16343722'],
#  ['1', '16344239', '16344478'],
#  ['1', '16349094', '16349234'],
#  ['1', '16350274', '16350443'],
#  ['1', '16351237', '16351406'],
#  ['1', '16352582', '16352762'],
#  ['1', '16353010', '16353128'],
#  ['1', '16353171', '16353290'],
#  ['1', '16353784', '16353950'],
#  ['1', '16354295', '16354420'],
#  ['1', '16354492', '16354634'],
#  ['1', '16355235', '16355360'],
#  ['1', '16355600', '16355814'],
#  ['1', '16356205', '16356315'],
#  ['1', '16356439', '16356590'],
#  ['1', '16356935', '16357189'],
#  ['1', '16358184', '16358358'],
#  ['1', '16358677', '16358806'],
#  ['1', '16358917', '16359041'],
#  ['1', '16359644', '16359771'],
#  ['1', '16360085', '16360173'],
#  ['1', '16370967', '16371107'],
#  ['1', '16372032', '16372201'],
#  ['1', '16373009', '16373178'],
#  ['1', '16374379', '16374559'],
#  ['1', '16374817', '16374935'],
#  ['1', '16374978', '16375097'],
#  ['1', '16375446', '16375760'],
#  ['1', '16376092', '16376217'],
#  ['1', '16376289', '16376431'],
#  ['1', '16376990', '16377115'],
#  ['1', '16377349', '16377563'],
#  ['1', '16377952', '16378062'],
#  ['1', '16378184', '16378335'],
#  ['1', '16378672', '16378926'],
#  ['1', '16380113', '16380287'],
#  ['1', '16381909', '16382038'],
#  ['1', '16382149', '16382273'],
#  ['1', '16382896', '16383023'],
#  ['1', '16383343', '16383431'],
#  ['1', '16451689', '16451835'],
#  ['1', '16455908', '16456104'],
#  ['1', '16456700', '16456934'],
#  ['1', '16458195', '16458385'],
#  ['1', '16458538', '16458788'],
#  ['1', '16458852', '16458954'],
#  ['1', '16459654', '16459883'],
#  ['1', '16459955', '16460121'],
#  ['1', '16460334', '16460430'],
#  ['1', '16460942', '16461082'],
#  ['1', '16461510', '16461704'],
#  ['1', '16462129', '16462285'],
#  ['1', '16464327', '16464700'],
#  ['1', '16464749', '16464945'],
#  ['1', '16474852', '16475562'],
#  ['1', '16477370', '16477478'],
#  ['1', '16482322', '16482447'],
#  ['1', '16725242', '16725337'],
#  ['1', '16725818', '16726036'],
#  ['1', '16727194', '16727407'],
#  ['1', '16730201', '16730359'],
#  ['1', '16730442', '16730554'],
#  ['1', '16731441', '16731619'],
#  ['1', '16735592', '16735718'],
#  ['1', '16736075', '16736558'],
#  ['1', '16747983', '16748072'],
#  ['1', '16748385', '16748486'],
#  ['1', '16757812', '16757886'],
#  ['1', '16891281', '16891433'],
#  ['1', '16892107', '16892324'],
#  ['1', '16892881', '16892974'],
#  ['1', '16893653', '16893866'],
#  ['1', '16894453', '16894545'],
#  ['1', '16895547', '16895751'],
#  ['1', '16899616', '16899708'],
#  ['1', '16900961', '16901207'],
#  ['1', '16901631', '16901744'],
#  ['1', '16902741', '16902996'],
#  ['1', '16903791', '16903934'],
#  ['1', '16905667', '16905917'],
#  ['1', '16907219', '16907471'],
#  ['1', '16907894', '16908007'],
#  ['1', '16909018', '16909273'],
#  ['1', '16910068', '16910211'],
#  ['1', '16911963', '16912213'],
#  ['1', '16913524', '16913776'],
#  ['1', '16914199', '16914312'],
#  ['1', '16915323', '16915578'],
#  ['1', '16916373', '16916516'],
#  ['1', '16918321', '16918536'],
#  ['1', '17312459', '17312873'],
#  ['1', '17312937', '17313147'],
#  ['1', '17313279', '17313471'],
#  ['1', '17313520', '17313784'],
#  ['1', '17314612', '17314749'],
#  ['1', '17314796', '17314989'],
#  ['1', '17316165', '17316285'],
#  ['1', '17316361', '17316518'],
#  ['1', '17316601', '17316802'],
#  ['1', '17318208', '17318373'],
#  ['1', '17318483', '17318644'],
#  ['1', '17318717', '17318917'],
#  ['1', '17318960', '17319096'],
#  ['1', '17320103', '17320350'],
#  ['1', '17322450', '17322679'],
#  ['1', '17322728', '17322815'],
#  ['1', '17322860', '17323011'],
#  ['1', '17323494', '17323690'],
#  ['1', '17326485', '17326657'],
#  ['1', '17326720', '17326827'],
#  ['1', '17326874', '17327049'],
#  ['1', '17328508', '17328618'],
#  ['1', '17328770', '17328888'],
#  ['1', '17330806', '17330926'],
#  ['1', '17331166', '17331336'],
#  ['1', '17331488', '17331587'],
#  ['1', '17331848', '17332071'],
#  ['1', '17332158', '17332293'],
#  ['1', '17338203', '17338253'],
#  ['1', '17345355', '17345473'],
#  ['1', '17349082', '17349245'],
#  ['1', '17350447', '17350589'],
#  ['1', '17354223', '17354380'],
#  ['1', '17355074', '17355251'],
#  ['1', '17359534', '17359660'],
#  ['1', '17371235', '17371403'],
#  ['1', '17380422', '17380534'],
#  ['1', '18958077', '18958202'],
#  ['1', '18960776', '18961052'],
#  ['1', '18961584', '18961754'],
#  ['1', '18962710', '18962885'],
#  ['1', '19018227', '19018467'],
#  ['1', '19027126', '19027332'],
#  ['1', '19029567', '19029810'],
#  ['1', '19062105', '19062550'],
#  ['1', '19071287', '19071440'],
#  ['1', '19166075', '19167041'],
#  ['1', '19168202', '19168366'],
#  ['1', '19175814', '19176064'],
#  ['1', '19180686', '19181500'],
#  ['1', '19183804', '19184145'],
#  ['1', '19185952', '19186174'],
#  ['1', '19199318', '19199471'],
#  ['1', '19200936', '19201095'],
#  ['1', '19201855', '19202017'],
#  ['1', '19202788', '19202981'],
#  ['1', '19203681', '19203769'],
#  ['1', '19203889', '19204126'],
#  ['1', '19205773', '19205887'],
#  ['1', '19208173', '19208401'],
#  ['1', '19209597', '19209712'],
#  ['1', '19209752', '19209942'],
#  ['1', '19211946', '19212142'],
#  ['1', '19212937', '19213025'],
#  ['1', '19215835', '19215968'],
#  ['1', '19216485', '19216619'],
#  ['1', '19228935', '19229037'],
#  ['1', '19609207', '19609406'],
#  ['1', '19610469', '19610639'],
#  ['1', '19611159', '19611299'],
#  ['1', '19611491', '19611628'],
#  ['1', '19612361', '19612506'],
#  ['1', '19612658', '19612886'],
#  ['1', '19614969', '19615223'],
#  ['1', '19630698', '19630900'],
#  ['1', '19632491', '19632661'],
#  ['1', '19633475', '19633615'],
#  ['1', '19633787', '19633924'],
#  ['1', '19634631', '19634776'],
#  ['1', '19634928', '19635156'],
#  ['1', '19638300', '19638638'],
#  ['1', '19992226', '19992980'],
#  ['1', '20005039', '20005238'],
#  ['1', '20005391', '20005878'],
#  ['1', '20302173', '20302356'],
#  ['1', '20304487', '20304634'],
#  ['1', '20304852', '20305037'],
#  ['1', '20305206', '20305286'],
#  ['1', '20411303', '20411383'],
#  ['1', '20412555', '20412740'],
#  ['1', '20416261', '20416408'],
#  ['1', '20417040', '20417202'],
#  ['1', '20440589', '20440772'],
#  ['1', '20441979', '20442126'],
#  ['1', '20442805', '20442990'],
#  ['1', '20445931', '20446011'],
#  ['1', '20915602', '20915796'],
#  ['1', '20931400', '20931552'],
#  ['1', '20940314', '20940412'],
#  ['1', '20944924', '20945081'],
#  ['1', '20960021', '20960448'],
#  ['1', '20964314', '20964642'],
#  ['1', '20966364', '20966505'],
#  ['1', '20970962', '20971185'],
#  ['1', '20972032', '20972236'],
#  ['1', '20974977', '20975145'],
#  ['1', '20975467', '20975744'],
#  ['1', '20976906', '20977204'],
#  ['1', '20978854', '20979041'],
#  ['1', '20979093', '20979240'],
#  ['1', '20979323', '20979484'],
#  ['1', '20980099', '20980287'],
#  ['1', '20980695', '20980884'],
#  ['1', '20981086', '20981220'],
#  ['1', '20981912', '20982047'],
#  ['1', '20982148', '20982292'],
#  ['1', '20982573', '20982700'],
#  ['1', '20987353', '20987504'],
#  ['1', '20987669', '20987914'],
#  ['1', '20991056', '20991275'],
#  ['1', '20992686', '20992844'],
#  ['1', '20996893', '20997004'],
#  ['1', '20998410', '20998709'],
#  ['1', '21009125', '21009397'],
#  ['1', '21011281', '21011533'],
#  ['1', '21012518', '21012639'],
#  ['1', '21013860', '21014457'],
#  ['1', '21016660', '21016848'],
#  ['1', '21024851', '21025001'],
#  ['1', '21030919', '21031412'],
#  ['1', '21036111', '21036341'],
#  ['1', '21039926', '21040068'],
#  ['1', '21041965', '21042152'],
#  ['1', '21043948', '21044219'],
#  ['1', '21546427', '21546644'],
#  ['1', '21548219', '21548355'],
#  ['1', '21551722', '21551953'],
#  ['1', '21553631', '21553739'],
#  ['1', '21554403', '21554554'],
#  ['1', '21560030', '21560174'],
#  ['1', '21562322', '21562440'],
#  ['1', '21563218', '21563357'],
#  ['1', '21564606', '21564757'],
#  ['1', '21571461', '21571616'],
#  ['1', '21573693', '21573876'],
#  ['1', '21582419', '21582651'],
#  ['1', '21583997', '21584103'],
#  ['1', '21585165', '21585352'],
#  ['1', '21586743', '21586905'],
#  ['1', '21599171', '21599424'],
#  ['1', '21605663', '21605947'],
#  ['1', '21616542', '21616711'],
#  ['1', '21616836', '21616927'],
#  ['1', '21671848', '21671891'],
#  ['1', '21880554', '21880655'],
#  ['1', '21887098', '21887258'],
#  ['1', '21887569', '21887725'],
#  ['1', '21889582', '21889797'],
#  ['1', '21890513', '21890729'],
#  ['1', '21894576', '21894760'],
#  ['1', '21896777', '21896887'],
#  ['1', '21900137', '21900312'],
#  ['1', '21902205', '21902437'],
#  ['1', '21902994', '21903154'],
#  ['1', '21903855', '21904161'],
#  ['1', '22149788', '22150001'],
#  ['1', '22150088', '22150232'],
#  ['1', '22150593', '22150717'],
#  ['1', '22150778', '22150889'],
#  ['1', '22151009', '22151128'],
#  ['1', '22151176', '22151292'],
#  ['1', '22154335', '22154432'],
#  ['1', '22154502', '22154665'],
#  ['1', '22154727', '22154939'],
#  ['1', '22155307', '22155592'],
#  ['1', '22155855', '22156117'],
#  ['1', '22156465', '22156604'],
#  ['1', '22157454', '22157603'],
#  ['1', '22157687', '22157837'],
#  ['1', '22157935', '22158075'],
#  ['1', '22158124', '22158309'],
#  ['1', '22158967', '22159119'],
#  ['1', '22159740', '22159897'],
#  ['1', '22159939', '22160127'],
#  ['1', '22160288', '22160438'],
#  ['1', '22161151', '22161458'],
#  ['1', '22162012', '22162150'],
#  ['1', '22163274', '22163519'],
#  ['1', '22165297', '22165598'],
#  ['1', '22165843', '22166063'],
#  ['1', '22166294', '22166530'],
#  ['1', '22167573', '22167798'],
#  ['1', '22168011', '22168186'],
#  ['1', '22168474', '22168655'],
#  ['1', '22168711', '22168893'],
#  ['1', '22169242', '22169434'],
#  ['1', '22169769', '22169951'],
#  ['1', '22170620', '22170812'],
#  ['1', '22172580', '22172768'],
#  ['1', '22172920', '22173112'],
#  ['1', '22173826', '22174005'],
#  ['1', '22174161', '22174353'],
#  ['1', '22174430', '22174606'],
#  ['1', '22175115', '22175307'],
#  ['1', '22175365', '22175544'],
#  ['1', '22176513', '22176705'],
#  ['1', '22176835', '22177011'],
#  ['1', '22178018', '22178210'],
#  ['1', '22178263', '22178439'],
#  ['1', '22178560', '22178746'],
#  ['1', '22179172', '22179345'],
#  ['1', '22179391', '22179583'],
#  ['1', '22180665', '22180856'],
#  ['1', '22181083', '22181278'],
#  ['1', '22181320', '22181496'],
#  ['1', '22181776', '22181959'],
#  ['1', '22181995', '22182188'],
#  ['1', '22182259', '22182425'],
#  ['1', '22183487', '22183708'],
#  ['1', '22183757', '22183898'],
#  ['1', '22186038', '22186189'],
#  ['1', '22186307', '22186515'],
#  ['1', '22186649', '22186748'],
#  ['1', '22188229', '22188356'],
#  ['1', '22188460', '22188628'],
#  ['1', '22190572', '22190726'],
#  ['1', '22191315', '22191586'],
#  ['1', '22191757', '22191878'],
#  ['1', '22192189', '22192322'],
#  ['1', '22198658', '22198890'],
#  ['1', '22199092', '22199273'],
#  ['1', '22199469', '22199604'],
#  ['1', '22199847', '22199937'],
#  ['1', '22200397', '22200524'],
#  ['1', '22200878', '22201046'],
#  ['1', '22201088', '22201242'],
#  ['1', '22201363', '22201515'],
#  ['1', '22202101', '22202260'],
#  ['1', '22202335', '22202555'],
#  ['1', '22202701', '22202918'],
#  ['1', '22202984', '22203165'],
#  ['1', '22204658', '22204766'],
#  ['1', '22204905', '22205004'],
#  ['1', '22205049', '22205176'],
#  ['1', '22205466', '22205634'],
#  ['1', '22206579', '22206767'],
#  ['1', '22206835', '22207072'],
#  ['1', '22207128', '22207348'],
#  ['1', '22207811', '22208015'],
#  ['1', '22211000', '22211187'],
#  ['1', '22211239', '22211431'],
#  ['1', '22211485', '22211670'],
#  ['1', '22211792', '22211964'],
#  ['1', '22213687', '22213847'],
#  ['1', '22213892', '22214187'],
#  ['1', '22214410', '22214579'],
#  ['1', '22216453', '22216654'],
#  ['1', '22216899', '22216998'],
#  ['1', '22217057', '22217207'],
#  ['1', '22222394', '22222479'],
#  ['1', '22222647', '22222823'],
#  ['1', '22263627', '22263730'],
#  ['1', '22446522', '22447030'],
#  ['1', '22447683', '22447866'],
#  ['1', '22447917', '22448089'],
#  ['1', '22456088', '22456364'],
#  ['1', '22469318', '22469435'],
#  ['1', '22816421', '22817158'],
#  ['1', '22817872', '22818046'],
#  ['1', '22827964', '22828197'],
#  ['1', '22828771', '22828954'],
#  ['1', '22832521', '22832754'],
#  ['1', '22834473', '22834650'],
#  ['1', '22835002', '22835244'],
#  ['1', '22835572', '22835746'],
#  ['1', '22837651', '22837860'],
#  ['1', '22838148', '22838647'],
#  ['1', '22839396', '22839643'],
#  ['1', '22843772', '22843977'],
#  ['1', '22846533', '22846788'],
#  ['1', '22847968', '22848171'],
#  ['1', '22848849', '22848976'],
#  ['1', '22850690', '22850957'],
#  ['1', '22852674', '22852909'],
#  ['1', '22964089', '22964292'],
#  ['1', '22965305', '22965920'],
#  ['1', '22970496', '22970717'],
#  ['1', '22973699', '22974296'],
#  ['1', '22985929', '22986156'],
#  ['1', '22987284', '22987899'],
#  ['1', '23037455', '23037556'],
#  ['1', '23107893', '23107998'],
#  ['1', '23110864', '23111589'],
#  ['1', '23189509', '23189705'],
#  ['1', '23191349', '23191725'],
#  ['1', '23208831', '23208996'],
#  ['1', '23219356', '23219559'],
#  ['1', '23221944', '23222093'],
#  ['1', '23222883', '23222991'],
#  ['1', '23232459', '23232622'],
#  ['1', '23233182', '23233470'],
#  ['1', '23234425', '23234681'],
#  ['1', '23235494', '23235684'],
#  ['1', '23236854', '23237088'],
#  ['1', '23238916', '23239112'],
#  ['1', '23239934', '23240083'],
#  ['1', '23885433', '23885530'],
#  ['1', '23885597', '23885937'],
#  ['1', '24018293', '24018339'],
#  ['1', '24019078', '24019269'],
#  ['1', '24020276', '24020423'],
#  ['1', '24021129', '24021301'],
#  ['1', '24022267', '24022418'],
#  ['1', '24022813', '24022883'],
#  ['1', '24122418', '24122517'],
#  ['1', '24122620', '24122775'],
#  ['1', '24122978', '24123096'],
#  ['1', '24123166', '24123292'],
#  ['1', '24123345', '24123452'],
#  ['1', '24123503', '24123657'],
#  ['1', '24124164', '24124381'],
#  ['1', '24124586', '24124740'],
#  ['1', '24125084', '24125240'],
#  ['1', '24125356', '24125517'],
#  ['1', '24128932', '24129074'],
#  ['1', '24130869', '24131035'],
#  ['1', '24134604', '24134833'],
#  ['1', '24137205', '24137309'],
#  ['1', '24140659', '24140848'],
#  ['1', '24143144', '24143280'],
#  ['1', '24143945', '24144093'],
#  ['1', '24146979', '24147103'],
#  ['1', '24151825', '24151925'],
#  ['1', '24172184', '24172365'],
#  ['1', '24172543', '24172683'],
#  ['1', '24175118', '24175349'],
#  ['1', '24180829', '24181070'],
#  ['1', '24186267', '24186413'],
#  ['1', '24189603', '24189781'],
#  ['1', '24191960', '24192135'],
#  ['1', '24194367', '24194796'],
#  ['1', '24201007', '24202127'],
#  ['1', '25228595', '25229177'],
#  ['1', '25233729', '25233928'],
#  ['1', '25245710', '25245855'],
#  ['1', '25254044', '25254241'],
#  ['1', '25256057', '25256379'],
#  ['1', '25290984', '25291082'],
#  ['1', '25599018', '25599206'],
#  ['1', '25611043', '25611270'],
#  ['1', '25617111', '25617302'],
#  ['1', '25627416', '25627604'],
#  ['1', '25627990', '25628197'],
#  ['1', '25629792', '25629970'],
#  ['1', '25633066', '25633240'],
#  ['1', '25643470', '25643590'],
#  ['1', '25648359', '25648473'],
#  ['1', '25655368', '25655435'],
#  ['1', '25688997', '25689064'],
#  ['1', '25696937', '25697051'],
#  ['1', '25701819', '25701939'],
#  ['1', '25712181', '25712355'],
#  ['1', '25715446', '25715624'],
#  ['1', '25717219', '25717426'],
#  ['1', '25718464', '25718652'],
#  ['1', '25729066', '25729257'],
#  ['1', '25735153', '25735380'],
#  ['1', '25747109', '25747297'],
#  ['1', '25870169', '25870297'],
#  ['1', '25880392', '25880575'],
#  ['1', '25881330', '25881483'],
#  ['1', '25883623', '25883778'],
#  ['1', '25889114', '25889227'],
#  ['1', '25889540', '25889664'],
#  ['1', '25890131', '25890302'],
#  ['1', '25891643', '25891718'],
#  ['1', '25893318', '25893503'],
#  ['1', '26126701', '26126924'],
#  ['1', '26127513', '26127671'],
#  ['1', '26128486', '26128628'],
#  ['1', '26131612', '26131786'],
#  ['1', '26135050', '26135300'],
#  ['1', '26135496', '26135661'],
#  ['1', '26136153', '26136331'],
#  ...]

# %%
def merge_gaps(gaps_list):
    
    gap_list = []
    
    for k, g in groupby(enumerate(gaps_list), lambda ix : ix[0] - ix[1]):
        gaps = list(map(itemgetter(1), g))
        gap_list.append([gaps[0], gaps[-1]])
        
    return gap_list

# %%
annotations = pr.read_gff3('../../sv_consequences/annotations/GRCh37_latest_genomic.gff.gz')

# %%
def map_chromosome(chrom):


    chrom_dict = {
        '1':'NC_000001.10',
        '2':'NC_000002.11',
        '3':'NC_000003.11',
        '4':'NC_000004.11',
        '5':'NC_000005.9',
        '6':'NC_000006.11',
        '7':'NC_000007.13',
        '8':'NC_000008.10',
        '9':'NC_000009.11',
        '10':'NC_000010.10',
        '11':'NC_000011.9',
        '12':'NC_000012.11',
        '13':'NC_000013.10',
        '14':'NC_000014.8',
        '15':'NC_000015.9',
        '16':'NC_000016.9',
        '17':'NC_000017.10',
        '18':'NC_000018.9',
        '19':'NC_000019.9',
        '20':'NC_000020.10',
        '21':'NC_000021.8',
        '22':'NC_000022.10',
        'X':'NC_000023.10',
        'Y':'NC_000024.9',
        'MT':'NC_012920.1'
    }

    return chrom_dict[chrom]



def get_overlapping_genome_features(chrom, pos, end, annotations_pr):

    chrom = map_chromosome(chrom)

    variant = {'Chromosome': [chrom], 'Start': [pos], 'End': [end]}

    variant_pr = pr.from_dict(variant)

    overlapping_genome_features = variant_pr.join(annotations_pr).as_df()
    
    return overlapping_genome_features

# %%
df = get_overlapping_genome_features('1', 25881330, 25881483,  annotations )

# %%
df.columns
# Out:
# Index(['Chromosome', 'Start', 'End', 'Source', 'Feature', 'Start_b', 'End_b',
#        'Score', 'Strand', 'Frame', 'ID', 'Dbxref', 'Name', 'chromosome',
#        'gbkey', 'genome', 'mol_type', 'description', 'gene', 'gene_biotype',
#        'pseudo', 'Parent', 'product', 'transcript_id', 'gene_synonym', 'tag',
#        'protein_id', 'Note', 'exception', 'inference', 'experiment',
#        'function', 'regulatory_class', 'standard_name', 'recombination_class',
#        'feat_class', 'rpt_type', 'rpt_unit_seq', 'partial', 'start_range',
#        'end_range', 'transl_except', 'anticodon', 'mobile_element_type',
#        'rpt_family', 'satellite', 'bound_moiety', 'Target',
#        'assembly_bases_aln', 'assembly_bases_seq', 'bit_score',
#        'blast_aligner', 'blast_score', 'common_component', 'e_value',
#        'filter_score', 'for_remapping', 'gap_count', 'hsp_percent_coverage',
#        'matchable_bases', 'matched_bases', 'num_ident', 'num_mismatch',
#        'pct_coverage', 'pct_coverage_hiqual', 'pct_identity_gap',
#        'pct_identity_gapopen_only', 'pct_identity_ungap', 'rank',
#        'weighted_identity', 'lxr_locAcc_currStat_120', 'not_for_annotation',
#        'Gap', 'consensus_splices', 'exon_identity', 'identity', 'idty',
#        'matches', 'product_coverage', 'splices', 'merge_aligner',
#        'lxr_locAcc_currStat_35', 'map', 'part', 'direction', 'rpt_unit_range',
#        'inversion_merge_aligner', 'exon_number', 'number', 'Is_circular',
#        'country', 'isolation-source', 'note', 'tissue-type', 'codons',
#        'transl_table'],
#       dtype='object')

# %%
df[['Name', 'Feature', 'transcript_id', 'Start', 'End', 'Start_b', 'End_b', 'codons', 'ID']]
# Out:
#           Name Feature transcript_id     Start       End   Start_b      End_b  \
# 0            1  region           NaN  25881330  25881483         0  249250621
# 1          NaN   match           NaN  25881330  25881483  25865075   25897377
# 2      LDLRAP1    gene           NaN  25881330  25881483  25870096   25895377
# 3  NM_015627.3    mRNA   NM_015627.3  25881330  25881483  25870096   25895377
# 4          NaN    exon   NM_015627.3  25881330  25881483  25881350   25881463
# 5  NP_056442.2     CDS           NaN  25881330  25881483  25881350   25881463
#
#   codons                                    ID
# 0    NaN             NC_000001.10:1..249250621
# 1    NaN  b285f1e1-c989-485b-8d94-4a5d954fc5d3
# 2    NaN                          gene-LDLRAP1
# 3    NaN                       rna-NM_015627.3
# 4    NaN                    exon-NM_015627.3-3
# 5    NaN                       cds-NP_056442.2

# %%
def parse_genome_features(overlapping_genome_features):

    gene_features = {'gene': None, 'pseudogene': None,'miRNA': None,'tRNA': None  }  
    transcript_features = {'transcript': None, 'mRNA': None, 'lnc_RNA': None,'primary_transcript': None, 'snoRNA': None, 'antisense_RNA': None, 'snRNA': None, 'guide_RNA': None, 'C_gene_segment': None, 'V_gene_segment': None, 'J_gene_segment': None, 'D_gene_segment': None, 'scRNA': None }

    genes = {}
    transcripts = {}
    transcript_exons = {}

    for row in overlapping_genome_features.itertuples():

        if row.Feature in gene_features:

            if row.Feature == 'miRNA':

                biotype = 'miRNA'

            elif row.Feature == 'tRNA':

                biotype = 'tRNA'

            else:

                biotype = row.gene_biotype

            genes[row.ID] = {'name': row.Name, 'start': row.Start_b, 'end': row.End_b, 'biotype': biotype}


        if row.Feature in transcript_features:


            if pd.isnull(row.Name):

                name = row.ID

            else:

                name = row.Name

            transcripts[row.ID] = {'name': row.Name, 'start': row.Start_b, 'end': row.End_b, 'gene': row.Parent}


    for row in overlapping_genome_features.itertuples():

        if row.Feature == 'exon':

            parent = row.Parent
            start = row.Start_b
            end = row.End_b

            if parent in transcripts:

                exon_n = row.ID.split('-')[-1]

                if row.transcript_id not in transcript_exons:

                    gene_id = genes[transcripts[parent]['gene']]

                    transcript_exons[row.transcript_id] = {'exons': [[start, end, exon_n]], 'gene':gene_id }

                else:

                    transcript_exons[row.transcript_id]['exons'].append([start, end, exon_n])

            elif parent in genes:

                if parent not in transcript_exons:

                    gene_id = genes[parent]

                    transcript_exons[parent] = {'exons': [[start, end, 'na']], 'gene':gene_id }

                else:

                    transcript_exons[parent]['exons'].append([start, end, 'na'])  


            else:

                print('oh no')

    parsed_overlapping_genome_features = {'transcripts': transcripts, 'genes': genes, 'transcript_exons': transcript_exons}
    
    return parsed_overlapping_genome_features

# %%
def get_region_stats(tabix_query, min_depths, bed_region_length, annotate=True):
    
    mean_cov_array = []
    pct_gtr_dict = {}
    
    region_length = 0
    
    gaps_dict = {}
    
    for min_depth in min_depths:
        
        gaps_dict[min_depth] = []
    
    for base in query:
                                                
        position = base[1]
        
        region_length = region_length +1
        
        depth = int(base[2])

        mean_cov_array.append(depth)
        
        # get pct > than for min depths
        for min_depth in min_depths:
            
            if depth >= min_depth:
        
                if min_depth not in pct_gtr_dict:
                
                    pct_gtr_dict[min_depth] = 1
                    
                else:
                    
                    pct_gtr_dict[min_depth] = pct_gtr_dict[min_depth] +1
                    
                    
                    
            if depth < min_depth:
                    
                gaps_dict[min_depth].append(int(position))
                    
    
    for min_depth in min_depths:
        
        gaps_dict[min_depth] = merge_gaps(gaps_dict[min_depth])
        try:
            pct_gtr_dict[min_depth] = pct_gtr_dict[min_depth] / region_length
            
        except KeyError:
            
            pct_gtr_dict[min_depth] = 0
                    
    mean_coverage = np.mean(mean_cov_array)
    
    if region_length != bed_region_length+1:
                
        error = 'no results for this region'
        
    else:
        
        error = 'none'
    
    results_dict = {'mean_coverage': mean_coverage, 'pct_gtr': pct_gtr_dict, 'gaps': gaps_dict, 'region_length': region_length, 'error': error}  
    
    return results_dict

# %%
i =  0

min_depths = [20,160]

bed_region_dict = {}

for region in bed_list:
    
    chrom = region[0]
    start = int(region[1])
    end = int(region[2])
    
    region_key = f'{chrom}:{start}-{end}'
    
    query = tb.query(chrom, start-1, end)
    
    bed_region_length = end - start
    
    bed_region_length = bed_region_length -1
    
    region_stats = get_region_stats(query, min_depths, bed_region_length)
    
    region_stats['chrom'] = chrom
    region_stats['start'] = start
    region_stats['end'] = end

    if region_key not in bed_region_dict:

        bed_region_dict[region_key] = region_stats

    
    i = i + 1
    
    if i > 1000:
        
        break

# %%
bed_region_dict
# Out:
# {'1:955532-955773': {'mean_coverage': 22.605809128630707,
#   'pct_gtr': {20: 0.6307053941908713, 160: 0},
#   'gaps': {20: [[955532, 955620]], 160: [[955532, 955772]]},
#   'region_length': 241,
#   'error': 'none',
#   'chrom': '1',
#   'start': 955532,
#   'end': 955773},
#  '1:957560-957862': {'mean_coverage': 78.77152317880795,
#   'pct_gtr': {20: 0.9635761589403974, 160: 0},
#   'gaps': {20: [[957851, 957861]], 160: [[957560, 957861]]},
#   'region_length': 302,
#   'error': 'none',
#   'chrom': '1',
#   'start': 957560,
#   'end': 957862},
#  '1:970636-970724': {'mean_coverage': 89.55681818181819,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[970636, 970723]]},
#   'region_length': 88,
#   'error': 'none',
#   'chrom': '1',
#   'start': 970636,
#   'end': 970724},
#  '1:976024-976280': {'mean_coverage': 93.1015625,
#   'pct_gtr': {20: 0.984375, 160: 0},
#   'gaps': {20: [[976276, 976279]], 160: [[976024, 976279]]},
#   'region_length': 256,
#   'error': 'none',
#   'chrom': '1',
#   'start': 976024,
#   'end': 976280},
#  '1:976532-976797': {'mean_coverage': 54.973584905660374,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[976532, 976796]]},
#   'region_length': 265,
#   'error': 'none',
#   'chrom': '1',
#   'start': 976532,
#   'end': 976797},
#  '1:976837-977102': {'mean_coverage': 63.17358490566038,
#   'pct_gtr': {20: 0.8830188679245283, 160: 0},
#   'gaps': {20: [[977071, 977101]], 160: [[976837, 977101]]},
#   'region_length': 265,
#   'error': 'none',
#   'chrom': '1',
#   'start': 976837,
#   'end': 977102},
#  '1:977315-977562': {'mean_coverage': 117.56275303643724,
#   'pct_gtr': {20: 1.0, 160: 0.145748987854251},
#   'gaps': {20: [],
#    160: [[977315, 977366],
#     [977384, 977398],
#     [977400, 977400],
#     [977406, 977406],
#     [977420, 977561]]},
#   'region_length': 247,
#   'error': 'none',
#   'chrom': '1',
#   'start': 977315,
#   'end': 977562},
#  '1:978598-978857': {'mean_coverage': 64.23552123552123,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[978598, 978856]]},
#   'region_length': 259,
#   'error': 'none',
#   'chrom': '1',
#   'start': 978598,
#   'end': 978857},
#  '1:978897-979132': {'mean_coverage': 124.19574468085106,
#   'pct_gtr': {20: 1.0, 160: 0.28085106382978725},
#   'gaps': {20: [],
#    160: [[978897, 978960],
#     [979021, 979022],
#     [979025, 979028],
#     [979033, 979131]]},
#   'region_length': 235,
#   'error': 'none',
#   'chrom': '1',
#   'start': 978897,
#   'end': 979132},
#  '1:979182-979423': {'mean_coverage': 110.65975103734439,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[979182, 979422]]},
#   'region_length': 241,
#   'error': 'none',
#   'chrom': '1',
#   'start': 979182,
#   'end': 979423},
#  '1:979468-979657': {'mean_coverage': 109.71957671957672,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[979468, 979656]]},
#   'region_length': 189,
#   'error': 'none',
#   'chrom': '1',
#   'start': 979468,
#   'end': 979657},
#  '1:979693-979839': {'mean_coverage': 71.8082191780822,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[979693, 979838]]},
#   'region_length': 146,
#   'error': 'none',
#   'chrom': '1',
#   'start': 979693,
#   'end': 979839},
#  '1:980520-980677': {'mean_coverage': 66.67515923566879,
#   'pct_gtr': {20: 0.7707006369426752, 160: 0},
#   'gaps': {20: [[980520, 980555]], 160: [[980520, 980676]]},
#   'region_length': 157,
#   'error': 'none',
#   'chrom': '1',
#   'start': 980520,
#   'end': 980677},
#  '1:980718-980923': {'mean_coverage': 66.08780487804879,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[980718, 980922]]},
#   'region_length': 205,
#   'error': 'none',
#   'chrom': '1',
#   'start': 980718,
#   'end': 980923},
#  '1:981092-981276': {'mean_coverage': 139.33152173913044,
#   'pct_gtr': {20: 1.0, 160: 0.22826086956521738},
#   'gaps': {20: [],
#    160: [[981092, 981127], [981169, 981169], [981171, 981275]]},
#   'region_length': 184,
#   'error': 'none',
#   'chrom': '1',
#   'start': 981092,
#   'end': 981276},
#  '1:981323-981488': {'mean_coverage': 74.06060606060606,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[981323, 981487]]},
#   'region_length': 165,
#   'error': 'none',
#   'chrom': '1',
#   'start': 981323,
#   'end': 981488},
#  '1:981519-981665': {'mean_coverage': 38.034246575342465,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[981519, 981664]]},
#   'region_length': 146,
#   'error': 'none',
#   'chrom': '1',
#   'start': 981519,
#   'end': 981665},
#  '1:981756-982135': {'mean_coverage': 146.30343007915567,
#   'pct_gtr': {20: 1.0, 160: 0.39841688654353563},
#   'gaps': {20: [],
#    160: [[981756, 981913],
#     [981915, 981915],
#     [982063, 982064],
#     [982067, 982089],
#     [982091, 982134]]},
#   'region_length': 379,
#   'error': 'none',
#   'chrom': '1',
#   'start': 981756,
#   'end': 982135},
#  '1:982179-982357': {'mean_coverage': 152.73033707865167,
#   'pct_gtr': {20: 1.0, 160: 0.4550561797752809},
#   'gaps': {20: [], 160: [[982179, 982208], [982290, 982356]]},
#   'region_length': 178,
#   'error': 'none',
#   'chrom': '1',
#   'start': 982179,
#   'end': 982357},
#  '1:982686-982854': {'mean_coverage': 84.58928571428571,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[982686, 982853]]},
#   'region_length': 168,
#   'error': 'none',
#   'chrom': '1',
#   'start': 982686,
#   'end': 982854},
#  '1:982932-983087': {'mean_coverage': 154.18064516129033,
#   'pct_gtr': {20: 1.0, 160: 0.5161290322580645},
#   'gaps': {20: [],
#    160: [[982932, 982946], [983023, 983027], [983032, 983086]]},
#   'region_length': 155,
#   'error': 'none',
#   'chrom': '1',
#   'start': 982932,
#   'end': 983087},
#  '1:983135-983295': {'mean_coverage': 115.9,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[983135, 983294]]},
#   'region_length': 160,
#   'error': 'none',
#   'chrom': '1',
#   'start': 983135,
#   'end': 983295},
#  '1:983371-983765': {'mean_coverage': 112.15989847715736,
#   'pct_gtr': {20: 0.9670050761421319, 160: 0.29441624365482233},
#   'gaps': {20: [[983752, 983764]],
#    160: [[983371, 983423],
#     [983526, 983526],
#     [983532, 983538],
#     [983542, 983543],
#     [983548, 983550],
#     [983553, 983764]]},
#   'region_length': 394,
#   'error': 'none',
#   'chrom': '1',
#   'start': 983371,
#   'end': 983765},
#  '1:984226-984459': {'mean_coverage': 106.24034334763948,
#   'pct_gtr': {20: 1.0, 160: 0.13733905579399142},
#   'gaps': {20: [],
#    160: [[984226, 984358], [984363, 984363], [984392, 984458]]},
#   'region_length': 233,
#   'error': 'none',
#   'chrom': '1',
#   'start': 984226,
#   'end': 984459},
#  '1:984595-984851': {'mean_coverage': 102.265625,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[984595, 984850]]},
#   'region_length': 256,
#   'error': 'none',
#   'chrom': '1',
#   'start': 984595,
#   'end': 984851},
#  '1:984925-985195': {'mean_coverage': 88.37777777777778,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[984925, 985194]]},
#   'region_length': 270,
#   'error': 'none',
#   'chrom': '1',
#   'start': 984925,
#   'end': 985195},
#  '1:985262-985437': {'mean_coverage': 125.18857142857142,
#   'pct_gtr': {20: 1.0, 160: 0.04},
#   'gaps': {20: [],
#    160: [[985262, 985315], [985319, 985320], [985325, 985436]]},
#   'region_length': 175,
#   'error': 'none',
#   'chrom': '1',
#   'start': 985262,
#   'end': 985437},
#  '1:985592-985729': {'mean_coverage': 75.45255474452554,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[985592, 985728]]},
#   'region_length': 137,
#   'error': 'none',
#   'chrom': '1',
#   'start': 985592,
#   'end': 985729},
#  '1:985786-985991': {'mean_coverage': 54.17560975609756,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[985786, 985990]]},
#   'region_length': 205,
#   'error': 'none',
#   'chrom': '1',
#   'start': 985786,
#   'end': 985991},
#  '1:986085-986237': {'mean_coverage': 83.96710526315789,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[986085, 986236]]},
#   'region_length': 152,
#   'error': 'none',
#   'chrom': '1',
#   'start': 986085,
#   'end': 986237},
#  '1:986612-986769': {'mean_coverage': 151.74522292993632,
#   'pct_gtr': {20: 1.0, 160: 0.5668789808917197},
#   'gaps': {20: [], 160: [[986612, 986668], [986758, 986768]]},
#   'region_length': 157,
#   'error': 'none',
#   'chrom': '1',
#   'start': 986612,
#   'end': 986769},
#  '1:986812-987045': {'mean_coverage': 100.02575107296137,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[986812, 987044]]},
#   'region_length': 233,
#   'error': 'none',
#   'chrom': '1',
#   'start': 986812,
#   'end': 987045},
#  '1:987087-987215': {'mean_coverage': 168.0234375,
#   'pct_gtr': {20: 1.0, 160: 0.6875},
#   'gaps': {20: [], 160: [[987087, 987101], [987190, 987214]]},
#   'region_length': 128,
#   'error': 'none',
#   'chrom': '1',
#   'start': 987087,
#   'end': 987215},
#  '1:989112-989377': {'mean_coverage': 89.64528301886793,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[989112, 989376]]},
#   'region_length': 265,
#   'error': 'none',
#   'chrom': '1',
#   'start': 989112,
#   'end': 989377},
#  '1:989807-989951': {'mean_coverage': 74.73611111111111,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[989807, 989950]]},
#   'region_length': 144,
#   'error': 'none',
#   'chrom': '1',
#   'start': 989807,
#   'end': 989951},
#  '1:990183-990381': {'mean_coverage': 104.23232323232324,
#   'pct_gtr': {20: 1.0, 160: 0.06565656565656566},
#   'gaps': {20: [], 160: [[990183, 990367]]},
#   'region_length': 198,
#   'error': 'none',
#   'chrom': '1',
#   'start': 990183,
#   'end': 990381},
#  '1:1146917-1147025': {'mean_coverage': 76.5925925925926,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1146917, 1147024]]},
#   'region_length': 108,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1146917,
#   'end': 1147025},
#  '1:1147063-1147232': {'mean_coverage': 18.49112426035503,
#   'pct_gtr': {20: 0.3668639053254438, 160: 0},
#   'gaps': {20: [[1147125, 1147231]], 160: [[1147063, 1147231]]},
#   'region_length': 169,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1147063,
#   'end': 1147232},
#  '1:1147301-1147538': {'mean_coverage': 77.43037974683544,
#   'pct_gtr': {20: 0.7890295358649789, 160: 0.1518987341772152},
#   'gaps': {20: [[1147301, 1147350]],
#    160: [[1147301, 1147500], [1147502, 1147502]]},
#   'region_length': 237,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1147301,
#   'end': 1147538},
#  '1:1147997-1148104': {'mean_coverage': 21.33644859813084,
#   'pct_gtr': {20: 0.7289719626168224, 160: 0},
#   'gaps': {20: [[1147997, 1148025]], 160: [[1147997, 1148103]]},
#   'region_length': 107,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1147997,
#   'end': 1148104},
#  '1:1148351-1148493': {'mean_coverage': 81.37323943661971,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1148351, 1148492]]},
#   'region_length': 142,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1148351,
#   'end': 1148493},
#  '1:1149022-1149185': {'mean_coverage': 57.852760736196316,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1149022, 1149184]]},
#   'region_length': 163,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1149022,
#   'end': 1149185},
#  '1:1149342-1149527': {'mean_coverage': 173.35135135135135,
#   'pct_gtr': {20: 1.0, 160: 0.8108108108108109},
#   'gaps': {20: [],
#    160: [[1149342, 1149358],
#     [1149360, 1149362],
#     [1149368, 1149369],
#     [1149373, 1149374],
#     [1149516, 1149526]]},
#   'region_length': 185,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1149342,
#   'end': 1149527},
#  '1:1167638-1168665': {'mean_coverage': 50.67672833495618,
#   'pct_gtr': {20: 0.46835443037974683, 160: 0.11002921129503408},
#   'gaps': {20: [[1167638, 1168021], [1168077, 1168223], [1168650, 1168664]],
#    160: [[1167638, 1168411], [1168525, 1168664]]},
#   'region_length': 1027,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1167638,
#   'end': 1168665},
#  '1:1266705-1266936': {'mean_coverage': 75.01298701298701,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1266705, 1266935]]},
#   'region_length': 231,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1266705,
#   'end': 1266936},
#  '1:1266997-1267338': {'mean_coverage': 216.90029325513197,
#   'pct_gtr': {20: 1.0, 160: 0.8885630498533724},
#   'gaps': {20: [], 160: [[1266997, 1267034]]},
#   'region_length': 341,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1266997,
#   'end': 1267338},
#  '1:1267383-1268206': {'mean_coverage': 139.32563791008505,
#   'pct_gtr': {20: 1.0, 160: 0.212636695018226},
#   'gaps': {20: [],
#    160: [[1267383, 1267423],
#     [1267425, 1267431],
#     [1267433, 1267435],
#     [1267468, 1267527],
#     [1267532, 1267534],
#     [1267538, 1267540],
#     [1267545, 1267545],
#     [1267550, 1267740],
#     [1267769, 1267769],
#     [1267771, 1268015],
#     [1268110, 1268110],
#     [1268113, 1268116],
#     [1268118, 1268205]]},
#   'region_length': 823,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1267383,
#   'end': 1268206},
#  '1:1268280-1268524': {'mean_coverage': 178.29508196721312,
#   'pct_gtr': {20: 1.0, 160: 0.6680327868852459},
#   'gaps': {20: [], 160: [[1268280, 1268300], [1268464, 1268523]]},
#   'region_length': 244,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1268280,
#   'end': 1268524},
#  '1:1268618-1268779': {'mean_coverage': 157.1552795031056,
#   'pct_gtr': {20: 1.0, 160: 0.453416149068323},
#   'gaps': {20: [],
#    160: [[1268618, 1268663],
#     [1268665, 1268668],
#     [1268706, 1268706],
#     [1268742, 1268778]]},
#   'region_length': 161,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1268618,
#   'end': 1268779},
#  '1:1268865-1269861': {'mean_coverage': 136.3413654618474,
#   'pct_gtr': {20: 0.9909638554216867, 160: 0.39056224899598396},
#   'gaps': {20: [[1269852, 1269860]],
#    160: [[1268865, 1268898], [1268980, 1269368], [1269677, 1269860]]},
#   'region_length': 996,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1268865,
#   'end': 1269861},
#  '1:1634328-1634458': {'mean_coverage': 0.0,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1634328, 1634457]], 160: [[1634328, 1634457]]},
#   'region_length': 130,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1634328,
#   'end': 1634458},
#  '1:1634498-1634728': {'mean_coverage': 0.8521739130434782,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1634498, 1634727]], 160: [[1634498, 1634727]]},
#   'region_length': 230,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1634498,
#   'end': 1634728},
#  '1:1634894-1635083': {'mean_coverage': 34.333333333333336,
#   'pct_gtr': {20: 0.91005291005291, 160: 0},
#   'gaps': {20: [[1634894, 1634910]], 160: [[1634894, 1635082]]},
#   'region_length': 189,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1634894,
#   'end': 1635083},
#  '1:1635242-1635399': {'mean_coverage': 89.63057324840764,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1635242, 1635398]]},
#   'region_length': 157,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1635242,
#   'end': 1635399},
#  '1:1635457-1635605': {'mean_coverage': 112.57432432432432,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1635457, 1635604]]},
#   'region_length': 148,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1635457,
#   'end': 1635605},
#  '1:1635641-1635803': {'mean_coverage': 92.46296296296296,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1635641, 1635802]]},
#   'region_length': 162,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1635641,
#   'end': 1635803},
#  '1:1635968-1636114': {'mean_coverage': 27.30821917808219,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1635968, 1636113]]},
#   'region_length': 146,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1635968,
#   'end': 1636114},
#  '1:1636322-1636484': {'mean_coverage': 50.25925925925926,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1636322, 1636483]]},
#   'region_length': 162,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1636322,
#   'end': 1636484},
#  '1:1637060-1637191': {'mean_coverage': 0.6183206106870229,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1637060, 1637190]], 160: [[1637060, 1637190]]},
#   'region_length': 131,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1637060,
#   'end': 1637191},
#  '1:1638827-1639043': {'mean_coverage': 26.47685185185185,
#   'pct_gtr': {20: 0.7916666666666666, 160: 0},
#   'gaps': {20: [[1638997, 1638997], [1638999, 1639042]],
#    160: [[1638827, 1639042]]},
#   'region_length': 216,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1638827,
#   'end': 1639043},
#  '1:1639598-1639704': {'mean_coverage': 6.40566037735849,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1639598, 1639703]], 160: [[1639598, 1639703]]},
#   'region_length': 106,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1639598,
#   'end': 1639704},
#  '1:1640212-1640411': {'mean_coverage': 0.7587939698492462,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1640212, 1640410]], 160: [[1640212, 1640410]]},
#   'region_length': 199,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1640212,
#   'end': 1640411},
#  '1:1640456-1640592': {'mean_coverage': 0.0,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1640456, 1640591]], 160: [[1640456, 1640591]]},
#   'region_length': 136,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1640456,
#   'end': 1640592},
#  '1:1640936-1641099': {'mean_coverage': 0.0,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1640936, 1641098]], 160: [[1640936, 1641098]]},
#   'region_length': 163,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1640936,
#   'end': 1641099},
#  '1:1643682-1643859': {'mean_coverage': 14.180790960451978,
#   'pct_gtr': {20: 0.24858757062146894, 160: 0},
#   'gaps': {20: [[1643682, 1643814]], 160: [[1643682, 1643858]]},
#   'region_length': 177,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1643682,
#   'end': 1643859},
#  '1:1647764-1647937': {'mean_coverage': 75.5028901734104,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1647764, 1647936]]},
#   'region_length': 173,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1647764,
#   'end': 1647937},
#  '1:1653014-1653170': {'mean_coverage': 88.6474358974359,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1653014, 1653169]]},
#   'region_length': 156,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1653014,
#   'end': 1653170},
#  '1:1654126-1654277': {'mean_coverage': 24.165562913907284,
#   'pct_gtr': {20: 0.8079470198675497, 160: 0},
#   'gaps': {20: [[1654248, 1654276]], 160: [[1654126, 1654276]]},
#   'region_length': 151,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1654126,
#   'end': 1654277},
#  '1:1950842-1950950': {'mean_coverage': 3.212962962962963,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[1950842, 1950949]], 160: [[1950842, 1950949]]},
#   'region_length': 108,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1950842,
#   'end': 1950950},
#  '1:1956360-1956513': {'mean_coverage': 200.640522875817,
#   'pct_gtr': {20: 1.0, 160: 0.9019607843137255},
#   'gaps': {20: [], 160: [[1956498, 1956512]]},
#   'region_length': 153,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1956360,
#   'end': 1956513},
#  '1:1956752-1956860': {'mean_coverage': 112.18518518518519,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1956752, 1956859]]},
#   'region_length': 108,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1956752,
#   'end': 1956860},
#  '1:1956936-1957197': {'mean_coverage': 103.08812260536398,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1956936, 1957196]]},
#   'region_length': 261,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1956936,
#   'end': 1957197},
#  '1:1958995-1959118': {'mean_coverage': 115.21138211382114,
#   'pct_gtr': {20: 1.0, 160: 0.2764227642276423},
#   'gaps': {20: [], 160: [[1959029, 1959117]]},
#   'region_length': 123,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1958995,
#   'end': 1959118},
#  '1:1959573-1959751': {'mean_coverage': 64.07303370786516,
#   'pct_gtr': {20: 0.9606741573033708, 160: 0},
#   'gaps': {20: [[1959744, 1959750]], 160: [[1959573, 1959750]]},
#   'region_length': 178,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1959573,
#   'end': 1959751},
#  '1:1960529-1960725': {'mean_coverage': 40.755102040816325,
#   'pct_gtr': {20: 0.7448979591836735, 160: 0},
#   'gaps': {20: [[1960675, 1960724]], 160: [[1960529, 1960724]]},
#   'region_length': 196,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1960529,
#   'end': 1960725},
#  '1:1960969-1961221': {'mean_coverage': 80.1547619047619,
#   'pct_gtr': {20: 0.9166666666666666, 160: 0},
#   'gaps': {20: [[1960969, 1960989]], 160: [[1960969, 1961220]]},
#   'region_length': 252,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1960969,
#   'end': 1961221},
#  '1:1961401-1961738': {'mean_coverage': 81.37388724035608,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[1961401, 1961737]]},
#   'region_length': 337,
#   'error': 'none',
#   'chrom': '1',
#   'start': 1961401,
#   'end': 1961738},
#  '1:2160185-2161194': {'mean_coverage': 93.80673934588701,
#   'pct_gtr': {20: 0.9127849355797819, 160: 0.14767096134786917},
#   'gaps': {20: [[2160185, 2160202], [2160351, 2160420]],
#    160: [[2160185, 2160513], [2160663, 2161193]]},
#   'region_length': 1009,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2160185,
#   'end': 2161194},
#  '1:2234396-2234562': {'mean_coverage': 108.32530120481928,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2234396, 2234561]]},
#   'region_length': 166,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2234396,
#   'end': 2234562},
#  '1:2234703-2234859': {'mean_coverage': 88.90384615384616,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2234703, 2234858]]},
#   'region_length': 156,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2234703,
#   'end': 2234859},
#  '1:2235258-2235561': {'mean_coverage': 61.20462046204621,
#   'pct_gtr': {20: 0.8745874587458746, 160: 0},
#   'gaps': {20: [[2235258, 2235295]], 160: [[2235258, 2235560]]},
#   'region_length': 303,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2235258,
#   'end': 2235561},
#  '1:2235711-2236044': {'mean_coverage': 88.93093093093093,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2235711, 2236043]]},
#   'region_length': 333,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2235711,
#   'end': 2236044},
#  '1:2237438-2237709': {'mean_coverage': 83.9520295202952,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2237438, 2237708]]},
#   'region_length': 271,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2237438,
#   'end': 2237709},
#  '1:2237995-2238224': {'mean_coverage': 49.68122270742358,
#   'pct_gtr': {20: 0.9956331877729258, 160: 0},
#   'gaps': {20: [[2238223, 2238223]], 160: [[2237995, 2238223]]},
#   'region_length': 229,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2237995,
#   'end': 2238224},
#  '1:2337184-2337293': {'mean_coverage': 113.73394495412845,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2337184, 2337292]]},
#   'region_length': 109,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2337184,
#   'end': 2337293},
#  '1:2337902-2338078': {'mean_coverage': 116.48295454545455,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2337902, 2338077]]},
#   'region_length': 176,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2337902,
#   'end': 2338078},
#  '1:2338138-2338414': {'mean_coverage': 161.09420289855072,
#   'pct_gtr': {20: 1.0, 160: 0.5507246376811594},
#   'gaps': {20: [], 160: [[2338138, 2338212], [2338365, 2338413]]},
#   'region_length': 276,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2338138,
#   'end': 2338414},
#  '1:2339870-2340317': {'mean_coverage': 191.8165548098434,
#   'pct_gtr': {20: 1.0, 160: 0.7785234899328859},
#   'gaps': {20: [], 160: [[2339870, 2339898], [2340247, 2340316]]},
#   'region_length': 447,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2339870,
#   'end': 2340317},
#  '1:2341789-2341910': {'mean_coverage': 95.35537190082644,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2341789, 2341909]]},
#   'region_length': 121,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2341789,
#   'end': 2341910},
#  '1:2343809-2343961': {'mean_coverage': 14.493421052631579,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[2343809, 2343960]], 160: [[2343809, 2343960]]},
#   'region_length': 152,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2343809,
#   'end': 2343961},
#  '1:2522411-2522548': {'mean_coverage': 66.65693430656934,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2522411, 2522547]]},
#   'region_length': 137,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2522411,
#   'end': 2522548},
#  '1:2522975-2523092': {'mean_coverage': 117.05982905982906,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2522975, 2523091]]},
#   'region_length': 117,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2522975,
#   'end': 2523092},
#  '1:2523350-2523486': {'mean_coverage': 70.26470588235294,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2523350, 2523485]]},
#   'region_length': 136,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2523350,
#   'end': 2523486},
#  '1:2524073-2524179': {'mean_coverage': 109.04716981132076,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2524073, 2524178]]},
#   'region_length': 106,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2524073,
#   'end': 2524179},
#  '1:2524251-2524425': {'mean_coverage': 91.2183908045977,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2524251, 2524424]]},
#   'region_length': 174,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2524251,
#   'end': 2524425},
#  '1:2525232-2525392': {'mean_coverage': 86.99375,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2525232, 2525391]]},
#   'region_length': 160,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2525232,
#   'end': 2525392},
#  '1:2525803-2525902': {'mean_coverage': 122.61616161616162,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2525803, 2525901]]},
#   'region_length': 99,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2525803,
#   'end': 2525902},
#  '1:2526208-2526352': {'mean_coverage': 171.84722222222223,
#   'pct_gtr': {20: 1.0, 160: 0.7361111111111112},
#   'gaps': {20: [], 160: [[2526312, 2526312], [2526315, 2526351]]},
#   'region_length': 144,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2526208,
#   'end': 2526352},
#  '1:2526694-2526818': {'mean_coverage': 46.645161290322584,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2526694, 2526817]]},
#   'region_length': 124,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2526694,
#   'end': 2526818},
#  '1:2527427-2527566': {'mean_coverage': 67.8273381294964,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2527427, 2527565]]},
#   'region_length': 139,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2527427,
#   'end': 2527566},
#  '1:2527979-2528148': {'mean_coverage': 41.23076923076923,
#   'pct_gtr': {20: 0.8757396449704142, 160: 0},
#   'gaps': {20: [[2528127, 2528147]], 160: [[2527979, 2528147]]},
#   'region_length': 169,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2527979,
#   'end': 2528148},
#  '1:2529625-2529759': {'mean_coverage': 115.55970149253731,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2529625, 2529758]]},
#   'region_length': 134,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2529625,
#   'end': 2529759},
#  '1:2530072-2530249': {'mean_coverage': 163.61581920903956,
#   'pct_gtr': {20: 1.0, 160: 0.6892655367231638},
#   'gaps': {20: [],
#    160: [[2530072, 2530077],
#     [2530177, 2530189],
#     [2530212, 2530212],
#     [2530214, 2530248]]},
#   'region_length': 177,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2530072,
#   'end': 2530249},
#  '1:2535302-2535432': {'mean_coverage': 149.6769230769231,
#   'pct_gtr': {20: 1.0, 160: 0.3076923076923077},
#   'gaps': {20: [], 160: [[2535342, 2535431]]},
#   'region_length': 130,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2535302,
#   'end': 2535432},
#  '1:2535565-2535740': {'mean_coverage': 111.49142857142857,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2535565, 2535739]]},
#   'region_length': 175,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2535565,
#   'end': 2535740},
#  '1:2536976-2537082': {'mean_coverage': 114.74528301886792,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2536976, 2537081]]},
#   'region_length': 106,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2536976,
#   'end': 2537082},
#  '1:2537666-2537825': {'mean_coverage': 80.05660377358491,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2537666, 2537824]]},
#   'region_length': 159,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2537666,
#   'end': 2537825},
#  '1:2538392-2538528': {'mean_coverage': 92.56617647058823,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2538392, 2538527]]},
#   'region_length': 136,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2538392,
#   'end': 2538528},
#  '1:2540757-2540878': {'mean_coverage': 71.5702479338843,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2540757, 2540877]]},
#   'region_length': 121,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2540757,
#   'end': 2540878},
#  '1:2541088-2541290': {'mean_coverage': 175.83168316831683,
#   'pct_gtr': {20: 1.0, 160: 0.6336633663366337},
#   'gaps': {20: [], 160: [[2541088, 2541130], [2541259, 2541289]]},
#   'region_length': 202,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2541088,
#   'end': 2541290},
#  '1:2542699-2542799': {'mean_coverage': 74.6,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[2542699, 2542798]]},
#   'region_length': 100,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2542699,
#   'end': 2542799},
#  '1:2543545-2543663': {'mean_coverage': 145.5593220338983,
#   'pct_gtr': {20: 1.0, 160: 0.2542372881355932},
#   'gaps': {20: [], 160: [[2543545, 2543594], [2543625, 2543662]]},
#   'region_length': 118,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2543545,
#   'end': 2543663},
#  '1:2560749-2560943': {'mean_coverage': 45.1958762886598,
#   'pct_gtr': {20: 0.9742268041237113, 160: 0},
#   'gaps': {20: [[2560749, 2560753]], 160: [[2560749, 2560942]]},
#   'region_length': 194,
#   'error': 'none',
#   'chrom': '1',
#   'start': 2560749,
#   'end': 2560943},
#  '1:3598909-3599014': {'mean_coverage': 74.21904761904761,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3598909, 3599013]]},
#   'region_length': 105,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3598909,
#   'end': 3599014},
#  '1:3599603-3599764': {'mean_coverage': 177.50310559006212,
#   'pct_gtr': {20: 1.0, 160: 0.7142857142857143},
#   'gaps': {20: [], 160: [[3599718, 3599763]]},
#   'region_length': 161,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3599603,
#   'end': 3599764},
#  '1:3607449-3607528': {'mean_coverage': 78.35443037974683,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3607449, 3607527]]},
#   'region_length': 79,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3607449,
#   'end': 3607528},
#  '1:3624092-3624375': {'mean_coverage': 139.92579505300353,
#   'pct_gtr': {20: 1.0, 160: 0.3003533568904594},
#   'gaps': {20: [],
#    160: [[3624092, 3624136], [3624220, 3624220], [3624223, 3624374]]},
#   'region_length': 283,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3624092,
#   'end': 3624375},
#  '1:3638564-3638791': {'mean_coverage': 136.95594713656388,
#   'pct_gtr': {20: 1.0, 160: 0.2422907488986784},
#   'gaps': {20: [], 160: [[3638564, 3638673], [3638729, 3638790]]},
#   'region_length': 227,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3638564,
#   'end': 3638791},
#  '1:3639897-3640053': {'mean_coverage': 117.8525641025641,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3639897, 3640052]]},
#   'region_length': 156,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3639897,
#   'end': 3640053},
#  '1:3643658-3643808': {'mean_coverage': 119.77333333333333,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3643658, 3643807]]},
#   'region_length': 150,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3643658,
#   'end': 3643808},
#  '1:3644171-3644354': {'mean_coverage': 211.0327868852459,
#   'pct_gtr': {20: 1.0, 160: 1.0},
#   'gaps': {20: [], 160: []},
#   'region_length': 183,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3644171,
#   'end': 3644354},
#  '1:3644672-3644801': {'mean_coverage': 171.95348837209303,
#   'pct_gtr': {20: 1.0, 160: 0.813953488372093},
#   'gaps': {20: [], 160: [[3644777, 3644800]]},
#   'region_length': 129,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3644672,
#   'end': 3644801},
#  '1:3645870-3646032': {'mean_coverage': 80.88888888888889,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3645870, 3646031]]},
#   'region_length': 162,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3645870,
#   'end': 3646032},
#  '1:3646543-3646732': {'mean_coverage': 105.28042328042328,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3646543, 3646731]]},
#   'region_length': 189,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3646543,
#   'end': 3646732},
#  '1:3647470-3647649': {'mean_coverage': 169.9050279329609,
#   'pct_gtr': {20: 1.0, 160: 0.5865921787709497},
#   'gaps': {20: [], 160: [[3647470, 3647484], [3647590, 3647648]]},
#   'region_length': 179,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3647470,
#   'end': 3647649},
#  '1:3648006-3648140': {'mean_coverage': 106.3731343283582,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[3648006, 3648139]]},
#   'region_length': 134,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3648006,
#   'end': 3648140},
#  '1:3649290-3649660': {'mean_coverage': 128.34054054054053,
#   'pct_gtr': {20: 1.0, 160: 0.016216216216216217},
#   'gaps': {20: [], 160: [[3649290, 3649475], [3649482, 3649659]]},
#   'region_length': 370,
#   'error': 'none',
#   'chrom': '1',
#   'start': 3649290,
#   'end': 3649660},
#  '1:5923304-5923485': {'mean_coverage': 131.08287292817678,
#   'pct_gtr': {20: 1.0, 160: 0.40331491712707185},
#   'gaps': {20: [], 160: [[5923304, 5923326], [5923400, 5923484]]},
#   'region_length': 181,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5923304,
#   'end': 5923485},
#  '1:5923929-5924113': {'mean_coverage': 126.42391304347827,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5923929, 5924112]]},
#   'region_length': 184,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5923929,
#   'end': 5924113},
#  '1:5924377-5924597': {'mean_coverage': 55.66818181818182,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5924377, 5924596]]},
#   'region_length': 220,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5924377,
#   'end': 5924597},
#  '1:5925141-5925353': {'mean_coverage': 81.50943396226415,
#   'pct_gtr': {20: 0.8254716981132075, 160: 0},
#   'gaps': {20: [[5925316, 5925352]], 160: [[5925141, 5925352]]},
#   'region_length': 212,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5925141,
#   'end': 5925353},
#  '1:5926412-5926538': {'mean_coverage': 68.43650793650794,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5926412, 5926537]]},
#   'region_length': 126,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5926412,
#   'end': 5926538},
#  '1:5927069-5927195': {'mean_coverage': 102.85714285714286,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5927069, 5927194]]},
#   'region_length': 126,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5927069,
#   'end': 5927195},
#  '1:5927779-5927976': {'mean_coverage': 79.00507614213198,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5927779, 5927975]]},
#   'region_length': 197,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5927779,
#   'end': 5927976},
#  '1:5933291-5933415': {'mean_coverage': 131.41129032258064,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5933291, 5933414]]},
#   'region_length': 124,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5933291,
#   'end': 5933415},
#  '1:5934510-5934737': {'mean_coverage': 111.66519823788546,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5934510, 5934736]]},
#   'region_length': 227,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5934510,
#   'end': 5934737},
#  '1:5934913-5935180': {'mean_coverage': 77.2434456928839,
#   'pct_gtr': {20: 0.9438202247191011, 160: 0},
#   'gaps': {20: [[5935165, 5935179]], 160: [[5934913, 5935179]]},
#   'region_length': 267,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5934913,
#   'end': 5935180},
#  '1:5937132-5937378': {'mean_coverage': 64.95121951219512,
#   'pct_gtr': {20: 0.9349593495934959, 160: 0},
#   'gaps': {20: [[5937132, 5937147]], 160: [[5937132, 5937377]]},
#   'region_length': 246,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5937132,
#   'end': 5937378},
#  '1:5940153-5940319': {'mean_coverage': 84.0421686746988,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5940153, 5940318]]},
#   'region_length': 166,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5940153,
#   'end': 5940319},
#  '1:5947325-5947546': {'mean_coverage': 67.34389140271493,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5947325, 5947545]]},
#   'region_length': 221,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5947325,
#   'end': 5947546},
#  '1:5950907-5951108': {'mean_coverage': 136.17412935323384,
#   'pct_gtr': {20: 1.0, 160: 0.40298507462686567},
#   'gaps': {20: [], 160: [[5950907, 5950945], [5951027, 5951107]]},
#   'region_length': 201,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5950907,
#   'end': 5951108},
#  '1:5964656-5964884': {'mean_coverage': 63.17982456140351,
#   'pct_gtr': {20: 0.9692982456140351, 160: 0},
#   'gaps': {20: [[5964656, 5964662]], 160: [[5964656, 5964883]]},
#   'region_length': 228,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5964656,
#   'end': 5964884},
#  '1:5965331-5965563': {'mean_coverage': 75.40948275862068,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5965331, 5965562]]},
#   'region_length': 232,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5965331,
#   'end': 5965563},
#  '1:5965671-5965863': {'mean_coverage': 70.953125,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5965671, 5965862]]},
#   'region_length': 192,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5965671,
#   'end': 5965863},
#  '1:5967154-5967302': {'mean_coverage': 50.472972972972975,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5967154, 5967301]]},
#   'region_length': 148,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5967154,
#   'end': 5967302},
#  '1:5969191-5969293': {'mean_coverage': 95.68627450980392,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5969191, 5969292]]},
#   'region_length': 102,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5969191,
#   'end': 5969293},
#  '1:5987688-5987867': {'mean_coverage': 113.00558659217877,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[5987688, 5987866]]},
#   'region_length': 179,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5987688,
#   'end': 5987867},
#  '1:5993186-5993409': {'mean_coverage': 51.596412556053814,
#   'pct_gtr': {20: 0.7757847533632287, 160: 0},
#   'gaps': {20: [[5993186, 5993235]], 160: [[5993186, 5993408]]},
#   'region_length': 223,
#   'error': 'none',
#   'chrom': '1',
#   'start': 5993186,
#   'end': 5993409},
#  '1:6007143-6007310': {'mean_coverage': 94.2814371257485,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6007143, 6007309]]},
#   'region_length': 167,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6007143,
#   'end': 6007310},
#  '1:6008109-6008331': {'mean_coverage': 63.189189189189186,
#   'pct_gtr': {20: 0.8693693693693694, 160: 0},
#   'gaps': {20: [[6008302, 6008330]], 160: [[6008109, 6008330]]},
#   'region_length': 222,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6008109,
#   'end': 6008331},
#  '1:6012739-6012916': {'mean_coverage': 94.51412429378531,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6012739, 6012915]]},
#   'region_length': 177,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6012739,
#   'end': 6012916},
#  '1:6021833-6022029': {'mean_coverage': 84.7704081632653,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6021833, 6022028]]},
#   'region_length': 196,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6021833,
#   'end': 6022029},
#  '1:6027338-6027443': {'mean_coverage': 96.81904761904762,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6027338, 6027442]]},
#   'region_length': 105,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6027338,
#   'end': 6027443},
#  '1:6029126-6029339': {'mean_coverage': 48.690140845070424,
#   'pct_gtr': {20: 0.8262910798122066, 160: 0},
#   'gaps': {20: [[6029302, 6029338]], 160: [[6029126, 6029338]]},
#   'region_length': 213,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6029126,
#   'end': 6029339},
#  '1:6038309-6038493': {'mean_coverage': 84.32065217391305,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6038309, 6038492]]},
#   'region_length': 184,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6038309,
#   'end': 6038493},
#  '1:6046194-6046369': {'mean_coverage': 131.25714285714287,
#   'pct_gtr': {20: 1.0, 160: 0.2},
#   'gaps': {20: [],
#    160: [[6046194, 6046204], [6046231, 6046250], [6046260, 6046368]]},
#   'region_length': 175,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6046194,
#   'end': 6046369},
#  '1:6100608-6100725': {'mean_coverage': 66.41880341880342,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6100608, 6100724]]},
#   'region_length': 117,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6100608,
#   'end': 6100725},
#  '1:6101870-6101952': {'mean_coverage': 151.4268292682927,
#   'pct_gtr': {20: 1.0, 160: 0.6341463414634146},
#   'gaps': {20: [],
#    160: [[6101870, 6101895], [6101905, 6101905], [6101949, 6101951]]},
#   'region_length': 82,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6101870,
#   'end': 6101952},
#  '1:6111576-6111834': {'mean_coverage': 140.84883720930233,
#   'pct_gtr': {20: 1.0, 160: 0.4689922480620155},
#   'gaps': {20: [],
#    160: [[6111576, 6111638], [6111759, 6111769], [6111771, 6111833]]},
#   'region_length': 258,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6111576,
#   'end': 6111834},
#  '1:6132794-6132878': {'mean_coverage': 122.46428571428571,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6132794, 6132877]]},
#   'region_length': 84,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6132794,
#   'end': 6132878},
#  '1:6133772-6133850': {'mean_coverage': 102.92307692307692,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6133772, 6133849]]},
#   'region_length': 78,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6133772,
#   'end': 6133850},
#  '1:6142234-6142354': {'mean_coverage': 85.65,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6142234, 6142353]]},
#   'region_length': 120,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6142234,
#   'end': 6142354},
#  '1:6145243-6145328': {'mean_coverage': 120.24705882352941,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6145243, 6145327]]},
#   'region_length': 85,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6145243,
#   'end': 6145328},
#  '1:6147506-6147591': {'mean_coverage': 89.61176470588235,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6147506, 6147590]]},
#   'region_length': 85,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6147506,
#   'end': 6147591},
#  '1:6149047-6149131': {'mean_coverage': 137.03571428571428,
#   'pct_gtr': {20: 1.0, 160: 0.05952380952380952},
#   'gaps': {20: [], 160: [[6149052, 6149130]]},
#   'region_length': 84,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6149047,
#   'end': 6149131},
#  '1:6150428-6150555': {'mean_coverage': 101.09448818897638,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6150428, 6150554]]},
#   'region_length': 127,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6150428,
#   'end': 6150555},
#  '1:6151302-6151387': {'mean_coverage': 102.16470588235295,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6151302, 6151386]]},
#   'region_length': 85,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6151302,
#   'end': 6151387},
#  '1:6154439-6154565': {'mean_coverage': 98.43650793650794,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6154439, 6154564]]},
#   'region_length': 126,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6154439,
#   'end': 6154565},
#  '1:6155362-6155523': {'mean_coverage': 72.57142857142857,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6155362, 6155522]]},
#   'region_length': 161,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6155362,
#   'end': 6155523},
#  '1:6155569-6155704': {'mean_coverage': 94.34074074074074,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6155569, 6155703]]},
#   'region_length': 135,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6155569,
#   'end': 6155704},
#  '1:6156675-6156836': {'mean_coverage': 186.4472049689441,
#   'pct_gtr': {20: 1.0, 160: 0.7577639751552795},
#   'gaps': {20: [], 160: [[6156797, 6156835]]},
#   'region_length': 161,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6156675,
#   'end': 6156836},
#  '1:6157308-6157437': {'mean_coverage': 184.33333333333334,
#   'pct_gtr': {20: 1.0, 160: 0.7751937984496124},
#   'gaps': {20: [],
#    160: [[6157404, 6157404], [6157408, 6157412], [6157414, 6157436]]},
#   'region_length': 129,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6157308,
#   'end': 6157437},
#  '1:6158524-6158651': {'mean_coverage': 135.1811023622047,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6158524, 6158650]]},
#   'region_length': 127,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6158524,
#   'end': 6158651},
#  '1:6484995-6485329': {'mean_coverage': 44.467065868263475,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6484995, 6485328]]},
#   'region_length': 334,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6484995,
#   'end': 6485329},
#  '1:6488265-6488499': {'mean_coverage': 43.675213675213676,
#   'pct_gtr': {20: 0.8205128205128205, 160: 0},
#   'gaps': {20: [[6488457, 6488498]], 160: [[6488265, 6488498]]},
#   'region_length': 234,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6488265,
#   'end': 6488499},
#  '1:6500293-6500520': {'mean_coverage': 73.59911894273128,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6500293, 6500519]]},
#   'region_length': 227,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6500293,
#   'end': 6500520},
#  '1:6500665-6500888': {'mean_coverage': 46.53811659192825,
#   'pct_gtr': {20: 0.7892376681614349, 160: 0},
#   'gaps': {20: [[6500841, 6500887]], 160: [[6500665, 6500887]]},
#   'region_length': 223,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6500665,
#   'end': 6500888},
#  '1:6500973-6501145': {'mean_coverage': 172.05232558139534,
#   'pct_gtr': {20: 1.0, 160: 0.7267441860465116},
#   'gaps': {20: [], 160: [[6500973, 6501017], [6501143, 6501144]]},
#   'region_length': 172,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6500973,
#   'end': 6501145},
#  '1:6504520-6504762': {'mean_coverage': 106.92561983471074,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6504520, 6504761]]},
#   'region_length': 242,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6504520,
#   'end': 6504762},
#  '1:6505703-6506015': {'mean_coverage': 103.71474358974359,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6505703, 6506014]]},
#   'region_length': 312,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6505703,
#   'end': 6506015},
#  '1:6508680-6509171': {'mean_coverage': 43.33808553971487,
#   'pct_gtr': {20: 0.36863543788187375, 160: 0},
#   'gaps': {20: [[6508861, 6509170]], 160: [[6508680, 6509170]]},
#   'region_length': 491,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6508680,
#   'end': 6509171},
#  '1:6511642-6511828': {'mean_coverage': 75.76881720430107,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6511642, 6511827]]},
#   'region_length': 186,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6511642,
#   'end': 6511828},
#  '1:6511872-6512176': {'mean_coverage': 51.25657894736842,
#   'pct_gtr': {20: 0.875, 160: 0},
#   'gaps': {20: [[6512138, 6512175]], 160: [[6511872, 6512175]]},
#   'region_length': 304,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6511872,
#   'end': 6512176},
#  '1:6517223-6517343': {'mean_coverage': 43.34166666666667,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6517223, 6517342]]},
#   'region_length': 120,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6517223,
#   'end': 6517343},
#  '1:6517400-6517452': {'mean_coverage': 74.96153846153847,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6517400, 6517451]]},
#   'region_length': 52,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6517400,
#   'end': 6517452},
#  '1:6520038-6520226': {'mean_coverage': 137.41489361702128,
#   'pct_gtr': {20: 1.0, 160: 0.34574468085106386},
#   'gaps': {20: [], 160: [[6520038, 6520056], [6520122, 6520225]]},
#   'region_length': 188,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6520038,
#   'end': 6520226},
#  '1:6521476-6521842': {'mean_coverage': 118.73770491803279,
#   'pct_gtr': {20: 1.0, 160: 0.25136612021857924},
#   'gaps': {20: [],
#    160: [[6521476, 6521598],
#     [6521600, 6521602],
#     [6521690, 6521690],
#     [6521695, 6521841]]},
#   'region_length': 366,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6521476,
#   'end': 6521842},
#  '1:6522033-6522254': {'mean_coverage': 70.58371040723982,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[6522033, 6522253]]},
#   'region_length': 221,
#   'error': 'none',
#   'chrom': '1',
#   'start': 6522033,
#   'end': 6522254},
#  '1:6522668-6522746': {'mean_coverage': 165.21794871794873,
# ...
#     [24125189, 24125189],
#     [24125196, 24125197],
#     [24125214, 24125214],
#     [24125216, 24125218],
#     [24125220, 24125239]]},
#   'region_length': 156,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24125084,
#   'end': 24125240},
#  '1:24125356-24125517': {'mean_coverage': 95.35403726708074,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24125356, 24125516]]},
#   'region_length': 161,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24125356,
#   'end': 24125517},
#  '1:24128932-24129074': {'mean_coverage': 103.04929577464789,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24128932, 24129073]]},
#   'region_length': 142,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24128932,
#   'end': 24129074},
#  '1:24130869-24131035': {'mean_coverage': 50.78915662650602,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24130869, 24131034]]},
#   'region_length': 166,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24130869,
#   'end': 24131035},
#  '1:24134604-24134833': {'mean_coverage': 188.75545851528383,
#   'pct_gtr': {20: 1.0, 160: 0.6550218340611353},
#   'gaps': {20: [], 160: [[24134604, 24134622], [24134773, 24134832]]},
#   'region_length': 229,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24134604,
#   'end': 24134833},
#  '1:24137205-24137309': {'mean_coverage': 100.23076923076923,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24137205, 24137308]]},
#   'region_length': 104,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24137205,
#   'end': 24137309},
#  '1:24140659-24140848': {'mean_coverage': 85.43915343915344,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24140659, 24140847]]},
#   'region_length': 189,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24140659,
#   'end': 24140848},
#  '1:24143144-24143280': {'mean_coverage': 65.48529411764706,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24143144, 24143279]]},
#   'region_length': 136,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24143144,
#   'end': 24143280},
#  '1:24143945-24144093': {'mean_coverage': 95.51351351351352,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24143945, 24144092]]},
#   'region_length': 148,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24143945,
#   'end': 24144093},
#  '1:24146979-24147103': {'mean_coverage': 81.16935483870968,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24146979, 24147102]]},
#   'region_length': 124,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24146979,
#   'end': 24147103},
#  '1:24151825-24151925': {'mean_coverage': 115.77,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24151825, 24151924]]},
#   'region_length': 100,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24151825,
#   'end': 24151925},
#  '1:24172184-24172365': {'mean_coverage': 69.66298342541437,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24172184, 24172364]]},
#   'region_length': 181,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24172184,
#   'end': 24172365},
#  '1:24172543-24172683': {'mean_coverage': 78.17857142857143,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24172543, 24172682]]},
#   'region_length': 140,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24172543,
#   'end': 24172683},
#  '1:24175118-24175349': {'mean_coverage': 79.87445887445888,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24175118, 24175348]]},
#   'region_length': 231,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24175118,
#   'end': 24175349},
#  '1:24180829-24181070': {'mean_coverage': 72.09128630705395,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24180829, 24181069]]},
#   'region_length': 241,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24180829,
#   'end': 24181070},
#  '1:24186267-24186413': {'mean_coverage': 83.43150684931507,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24186267, 24186412]]},
#   'region_length': 146,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24186267,
#   'end': 24186413},
#  '1:24189603-24189781': {'mean_coverage': 67.85393258426966,
#   'pct_gtr': {20: 0.8146067415730337, 160: 0},
#   'gaps': {20: [[24189748, 24189780]], 160: [[24189603, 24189780]]},
#   'region_length': 178,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24189603,
#   'end': 24189781},
#  '1:24191960-24192135': {'mean_coverage': 99.05142857142857,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[24191960, 24192134]]},
#   'region_length': 175,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24191960,
#   'end': 24192135},
#  '1:24194367-24194796': {'mean_coverage': 92.38694638694639,
#   'pct_gtr': {20: 0.916083916083916, 160: 0.25874125874125875},
#   'gaps': {20: [[24194367, 24194402]],
#    160: [[24194367, 24194550], [24194554, 24194556], [24194665, 24194795]]},
#   'region_length': 429,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24194367,
#   'end': 24194796},
#  '1:24201007-24202127': {'mean_coverage': 21.358035714285716,
#   'pct_gtr': {20: 0.5669642857142857, 160: 0},
#   'gaps': {20: [[24201007, 24201141],
#     [24201312, 24201432],
#     [24201454, 24201464],
#     [24201672, 24201681],
#     [24201726, 24201726],
#     [24201739, 24201747],
#     [24201749, 24201758],
#     [24201763, 24201857],
#     [24202034, 24202126]],
#    160: [[24201007, 24202126]]},
#   'region_length': 1120,
#   'error': 'none',
#   'chrom': '1',
#   'start': 24201007,
#   'end': 24202127},
#  '1:25228595-25229177': {'mean_coverage': 111.79725085910653,
#   'pct_gtr': {20: 1.0, 160: 0.140893470790378},
#   'gaps': {20: [],
#    160: [[25228595, 25228764], [25228776, 25228778], [25228850, 25229176]]},
#   'region_length': 582,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25228595,
#   'end': 25229177},
#  '1:25233729-25233928': {'mean_coverage': 108.66331658291458,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25233729, 25233927]]},
#   'region_length': 199,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25233729,
#   'end': 25233928},
#  '1:25245710-25245855': {'mean_coverage': 61.95862068965517,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25245710, 25245854]]},
#   'region_length': 145,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25245710,
#   'end': 25245855},
#  '1:25254044-25254241': {'mean_coverage': 150.26903553299493,
#   'pct_gtr': {20: 1.0, 160: 0.5685279187817259},
#   'gaps': {20: [], 160: [[25254044, 25254080], [25254193, 25254240]]},
#   'region_length': 197,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25254044,
#   'end': 25254241},
#  '1:25256057-25256379': {'mean_coverage': 33.12111801242236,
#   'pct_gtr': {20: 0.40372670807453415, 160: 0},
#   'gaps': {20: [[25256187, 25256378]], 160: [[25256057, 25256378]]},
#   'region_length': 322,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25256057,
#   'end': 25256379},
#  '1:25290984-25291082': {'mean_coverage': 76.58163265306122,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25290984, 25291081]]},
#   'region_length': 98,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25290984,
#   'end': 25291082},
#  '1:25599018-25599206': {'mean_coverage': 63.75,
#   'pct_gtr': {20: 0.9308510638297872, 160: 0},
#   'gaps': {20: [[25599193, 25599205]], 160: [[25599018, 25599205]]},
#   'region_length': 188,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25599018,
#   'end': 25599206},
#  '1:25611043-25611270': {'mean_coverage': 126.45374449339207,
#   'pct_gtr': {20: 1.0, 160: 0.022026431718061675},
#   'gaps': {20: [],
#    160: [[25611043, 25611140], [25611143, 25611146], [25611150, 25611269]]},
#   'region_length': 227,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25611043,
#   'end': 25611270},
#  '1:25617111-25617302': {'mean_coverage': 81.15706806282722,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25617111, 25617301]]},
#   'region_length': 191,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25617111,
#   'end': 25617302},
#  '1:25627416-25627604': {'mean_coverage': 59.026595744680854,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25627416, 25627603]]},
#   'region_length': 188,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25627416,
#   'end': 25627604},
#  '1:25627990-25628197': {'mean_coverage': 88.512077294686,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25627990, 25628196]]},
#   'region_length': 207,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25627990,
#   'end': 25628197},
#  '1:25629792-25629970': {'mean_coverage': 32.348314606741575,
#   'pct_gtr': {20: 0.7191011235955056, 160: 0},
#   'gaps': {20: [[25629792, 25629841]], 160: [[25629792, 25629969]]},
#   'region_length': 178,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25629792,
#   'end': 25629970},
#  '1:25633066-25633240': {'mean_coverage': 90.683908045977,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25633066, 25633239]]},
#   'region_length': 174,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25633066,
#   'end': 25633240},
#  '1:25643470-25643590': {'mean_coverage': 1.65,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[25643470, 25643589]], 160: [[25643470, 25643589]]},
#   'region_length': 120,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25643470,
#   'end': 25643590},
#  '1:25648359-25648473': {'mean_coverage': 63.43859649122807,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25648359, 25648472]]},
#   'region_length': 114,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25648359,
#   'end': 25648473},
#  '1:25655368-25655435': {'mean_coverage': 24.80597014925373,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25655368, 25655434]]},
#   'region_length': 67,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25655368,
#   'end': 25655435},
#  '1:25688997-25689064': {'mean_coverage': 53.940298507462686,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25688997, 25689063]]},
#   'region_length': 67,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25688997,
#   'end': 25689064},
#  '1:25696937-25697051': {'mean_coverage': 101.16666666666667,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25696937, 25697050]]},
#   'region_length': 114,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25696937,
#   'end': 25697051},
#  '1:25701819-25701939': {'mean_coverage': 178.55833333333334,
#   'pct_gtr': {20: 1.0, 160: 0.7416666666666667},
#   'gaps': {20: [], 160: [[25701819, 25701835], [25701925, 25701938]]},
#   'region_length': 120,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25701819,
#   'end': 25701939},
#  '1:25712181-25712355': {'mean_coverage': 153.5977011494253,
#   'pct_gtr': {20: 1.0, 160: 0.5747126436781609},
#   'gaps': {20: [], 160: [[25712181, 25712242], [25712343, 25712354]]},
#   'region_length': 174,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25712181,
#   'end': 25712355},
#  '1:25715446-25715624': {'mean_coverage': 50.47191011235955,
#   'pct_gtr': {20: 0.8426966292134831, 160: 0},
#   'gaps': {20: [[25715596, 25715623]], 160: [[25715446, 25715623]]},
#   'region_length': 178,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25715446,
#   'end': 25715624},
#  '1:25717219-25717426': {'mean_coverage': 147.36231884057972,
#   'pct_gtr': {20: 1.0, 160: 0.46859903381642515},
#   'gaps': {20: [],
#    160: [[25717219, 25717262], [25717356, 25717357], [25717362, 25717425]]},
#   'region_length': 207,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25717219,
#   'end': 25717426},
#  '1:25718464-25718652': {'mean_coverage': 117.75531914893617,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25718464, 25718651]]},
#   'region_length': 188,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25718464,
#   'end': 25718652},
#  '1:25729066-25729257': {'mean_coverage': 131.98429319371726,
#   'pct_gtr': {20: 1.0, 160: 0.20418848167539266},
#   'gaps': {20: [],
#    160: [[25729066, 25729090], [25729128, 25729138], [25729141, 25729256]]},
#   'region_length': 191,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25729066,
#   'end': 25729257},
#  '1:25735153-25735380': {'mean_coverage': 63.56828193832599,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25735153, 25735379]]},
#   'region_length': 227,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25735153,
#   'end': 25735380},
#  '1:25747109-25747297': {'mean_coverage': 58.91489361702128,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25747109, 25747296]]},
#   'region_length': 188,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25747109,
#   'end': 25747297},
#  '1:25870169-25870297': {'mean_coverage': 4.640625,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[25870169, 25870296]], 160: [[25870169, 25870296]]},
#   'region_length': 128,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25870169,
#   'end': 25870297},
#  '1:25880392-25880575': {'mean_coverage': 143.4207650273224,
#   'pct_gtr': {20: 1.0, 160: 0.4426229508196721},
#   'gaps': {20: [], 160: [[25880392, 25880452], [25880534, 25880574]]},
#   'region_length': 183,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25880392,
#   'end': 25880575},
#  '1:25881330-25881483': {'mean_coverage': 77.42483660130719,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25881330, 25881482]]},
#   'region_length': 153,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25881330,
#   'end': 25881483},
#  '1:25883623-25883778': {'mean_coverage': 109.36774193548388,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25883623, 25883777]]},
#   'region_length': 155,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25883623,
#   'end': 25883778},
#  '1:25889114-25889227': {'mean_coverage': 84.77876106194691,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25889114, 25889226]]},
#   'region_length': 113,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25889114,
#   'end': 25889227},
#  '1:25889540-25889664': {'mean_coverage': 36.28225806451613,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25889540, 25889663]]},
#   'region_length': 124,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25889540,
#   'end': 25889664},
#  '1:25890131-25890302': {'mean_coverage': 82.75438596491227,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25890131, 25890301]]},
#   'region_length': 171,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25890131,
#   'end': 25890302},
#  '1:25891643-25891718': {'mean_coverage': 69.30666666666667,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[25891643, 25891717]]},
#   'region_length': 75,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25891643,
#   'end': 25891718},
#  '1:25893318-25893503': {'mean_coverage': 253.84324324324325,
#   'pct_gtr': {20: 1.0, 160: 1.0},
#   'gaps': {20: [], 160: []},
#   'region_length': 185,
#   'error': 'none',
#   'chrom': '1',
#   'start': 25893318,
#   'end': 25893503},
#  '1:26126701-26126924': {'mean_coverage': 0.37668161434977576,
#   'pct_gtr': {20: 0, 160: 0},
#   'gaps': {20: [[26126701, 26126923]], 160: [[26126701, 26126923]]},
#   'region_length': 223,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26126701,
#   'end': 26126924},
#  '1:26127513-26127671': {'mean_coverage': 54.879746835443036,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[26127513, 26127670]]},
#   'region_length': 158,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26127513,
#   'end': 26127671},
#  '1:26128486-26128628': {'mean_coverage': 36.33802816901409,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[26128486, 26128627]]},
#   'region_length': 142,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26128486,
#   'end': 26128628},
#  '1:26131612-26131786': {'mean_coverage': 57.775862068965516,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[26131612, 26131785]]},
#   'region_length': 174,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26131612,
#   'end': 26131786},
#  '1:26135050-26135300': {'mean_coverage': 199.116,
#   'pct_gtr': {20: 1.0, 160: 0.68},
#   'gaps': {20: [], 160: [[26135050, 26135076], [26135247, 26135299]]},
#   'region_length': 250,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26135050,
#   'end': 26135300},
#  '1:26135496-26135661': {'mean_coverage': 89.61212121212121,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[26135496, 26135660]]},
#   'region_length': 165,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26135496,
#   'end': 26135661},
#  '1:26136153-26136331': {'mean_coverage': 60.32022471910113,
#   'pct_gtr': {20: 1.0, 160: 0},
#   'gaps': {20: [], 160: [[26136153, 26136330]]},
#   'region_length': 178,
#   'error': 'none',
#   'chrom': '1',
#   'start': 26136153,
#   'end': 26136331},
#  ...}

# %%
df_row_list = []

columns = ['mean_coverage',
              'region_length',
              'error',
              'chrom',
              'start',
              'end',
              'gaps']

for cov in min_depths:
        
    columns.append(f'pct_gtr_{cov}x')


for key in bed_region_dict:
    
    mean_coverage = bed_region_dict[key]['mean_coverage']
    region_length = bed_region_dict[key]['region_length']
    error = bed_region_dict[key]['error']
    chrom = bed_region_dict[key]['chrom']
    start = bed_region_dict[key]['start']
    end = bed_region_dict[key]['end']
    gaps = bed_region_dict[key]['gaps']
    
    new_row = [mean_coverage,region_length, error, chrom, start, end, gaps]
    
    for cov in min_depths:
                
        new_row.append(bed_region_dict[key]['pct_gtr'][cov])
        
    df_row_list.append(new_row)

# %%
df = pd.DataFrame(df_row_list, columns=columns)

# %%
df
# Out:
#       mean_coverage  region_length error chrom     start       end  \
# 0         22.605809            241  none     1    955532    955773
# 1         78.771523            302  none     1    957560    957862
# 2         89.556818             88  none     1    970636    970724
# 3         93.101562            256  none     1    976024    976280
# 4         54.973585            265  none     1    976532    976797
# ...             ...            ...   ...   ...       ...       ...
# 996       57.775862            174  none     1  26131612  26131786
# 997      199.116000            250  none     1  26135050  26135300
# 998       89.612121            165  none     1  26135496  26135661
# 999       60.320225            178  none     1  26136153  26136331
# 1000      52.122951            122  none     1  26137924  26138046
#
#                                                    gaps  pct_gtr_20x  \
# 0     {20: [[955532, 955620]], 160: [[955532, 955772]]}     0.630705
# 1     {20: [[957851, 957861]], 160: [[957560, 957861]]}     0.963576
# 2                     {20: [], 160: [[970636, 970723]]}     1.000000
# 3     {20: [[976276, 976279]], 160: [[976024, 976279]]}     0.984375
# 4                     {20: [], 160: [[976532, 976796]]}     1.000000
# ...                                                 ...          ...
# 996               {20: [], 160: [[26131612, 26131785]]}     1.000000
# 997   {20: [], 160: [[26135050, 26135076], [26135247...     1.000000
# 998               {20: [], 160: [[26135496, 26135660]]}     1.000000
# 999               {20: [], 160: [[26136153, 26136330]]}     1.000000
# 1000              {20: [], 160: [[26137924, 26138045]]}     1.000000
#
#       pct_gtr_160x
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
# ...            ...
# 996           0.00
# 997           0.68
# 998           0.00
# 999           0.00
# 1000          0.00
#
# [1001 rows x 9 columns]

# %%
def annotate_row
# Out:
#        mean_coverage  region_length error chrom     start       end  \
# 0          31.995851            241  none     1    955532    955773
# 1         113.784768            302  none     1    957560    957862
# 2         145.988636             88  none     1    970636    970724
# 3         115.148438            256  none     1    976024    976280
# 4          44.147170            265  none     1    976532    976797
# ...              ...            ...   ...   ...       ...       ...
# 62157       0.000000            242  none     Y  59337928  59338170
# 62158       0.000000            146  none     Y  59338733  59338879
# 62159       0.000000            125  none     Y  59340173  59340298
# 62160       0.000000            631  none     Y  59342466  59343097
# 62161       0.000000          16569  none    MT         0     16569
#
#                                                     gaps  pct_gtr_20x  \
# 0      {20: [[955532, 955617]], 160: [[955532, 955772]]}     0.643154
# 1      {20: [], 160: [[957560, 957674], [957726, 9578...     1.000000
# 2      {20: [], 160: [[970636, 970654], [970681, 9707...     1.000000
# 3      {20: [[976265, 976279]], 160: [[976024, 976049...     0.941406
# 4                      {20: [], 160: [[976532, 976796]]}     1.000000
# ...                                                  ...          ...
# 62157  {20: [[59337928, 59338169]], 160: [[59337928, ...     0.000000
# 62158  {20: [[59338733, 59338878]], 160: [[59338733, ...     0.000000
# 62159  {20: [[59340173, 59340297]], 160: [[59340173, ...     0.000000
# 62160  {20: [[59342466, 59343096]], 160: [[59342466, ...     0.000000
# 62161              {20: [[0, 16568]], 160: [[0, 16568]]}     0.000000
#
#        pct_gtr_160x                               sample_id
# 0          0.000000  191010_D00501_0366_BH5JWHBCX3_18M01315
# 1          0.168874  191010_D00501_0366_BH5JWHBCX3_18M01315
# 2          0.295455  191010_D00501_0366_BH5JWHBCX3_18M01315
# 3          0.300781  191010_D00501_0366_BH5JWHBCX3_18M01315
# 4          0.000000  191010_D00501_0366_BH5JWHBCX3_18M01315
# ...             ...                                     ...
# 62157      0.000000       191010_D00501_0366_BH5JWHBCX3_NTC
# 62158      0.000000       191010_D00501_0366_BH5JWHBCX3_NTC
# 62159      0.000000       191010_D00501_0366_BH5JWHBCX3_NTC
# 62160      0.000000       191010_D00501_0366_BH5JWHBCX3_NTC
# 62161      0.000000       191010_D00501_0366_BH5JWHBCX3_NTC
#
# [248648 rows x 10 columns]
